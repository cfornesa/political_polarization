# %% [markdown]
# # Library and Data Imports and Standardization

# %%
# Make the imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import sklearn as sk

# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# Import ordinal encoder
from sklearn.preprocessing import OrdinalEncoder

# Import pickle
import pickle
from sklearn.manifold import TSNE

# Import random
import random
random.seed(42)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Import the datasets

# %%
pickle_path = '/content/drive/My Drive/Online MSDS/MOD C2/Political Polarization/pickle/'

# %%
# Open the pickled embeddings
with open(f'{pickle_path}convabuse_X_train_combined_SMOTE.pkl', 'rb') as f:
    convabuse_X_train = pickle.load(f)
with open(f'{pickle_path}convabuse_X_test_combined_SMOTE.pkl', 'rb') as f:
    convabuse_X_test = pickle.load(f)
with open(f'{pickle_path}convabuse_y_train_combined_SMOTE.pkl', 'rb') as f:
    convabuse_y_train = pickle.load(f)
with open(f'{pickle_path}convabuse_y_test_combined_SMOTE.pkl', 'rb') as f:
    convabuse_y_test = pickle.load(f)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}convabuse_prev_agent_X_train_SMOTE.pkl', 'rb') as f:
    convabuse_prev_agent_X_train = pickle.load(f)
with open(f'{pickle_path}convabuse_prev_agent_X_test_SMOTE.pkl', 'rb') as f:
    convabuse_prev_agent_X_test = pickle.load(f)
with open(f'{pickle_path}convabuse_prev_agent_y_train_SMOTE.pkl', 'rb') as f:
    convabuse_prev_agent_y_train = pickle.load(f)
with open(f'{pickle_path}convabuse_prev_agent_y_test_SMOTE.pkl', 'rb') as f:
    convabuse_prev_agent_y_test = pickle.load(f)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}convabuse_prev_user_X_train_SMOTE.pkl', 'rb') as f:
    convabuse_prev_user_X_train = pickle.load(f)
with open(f'{pickle_path}convabuse_prev_user_X_test_SMOTE.pkl', 'rb') as f:
    convabuse_prev_user_X_test = pickle.load(f)
with open(f'{pickle_path}convabuse_prev_user_y_train_SMOTE.pkl', 'rb') as f:
    convabuse_prev_user_y_train = pickle.load(f)
with open(f'{pickle_path}convabuse_prev_user_y_test_SMOTE.pkl', 'rb') as f:
    convabuse_prev_user_y_test = pickle.load(f)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}convabuse_agent_X_train_SMOTE.pkl', 'rb') as e:
    convabuse_agent_X_train = pickle.load(e)
with open(f'{pickle_path}convabuse_agent_X_test_SMOTE.pkl', 'rb') as f:
    convabuse_agent_X_test = pickle.load(f)
with open(f'{pickle_path}convabuse_agent_y_train_SMOTE.pkl', 'rb') as g:
    convabuse_agent_y_train = pickle.load(g)
with open(f'{pickle_path}convabuse_agent_y_test_SMOTE.pkl', 'rb') as h:
    convabuse_agent_y_test = pickle.load(h)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}convabuse_user_X_train_SMOTE.pkl', 'rb') as e:
    convabuse_user_X_train = pickle.load(e)
with open(f'{pickle_path}convabuse_user_X_test_SMOTE.pkl', 'rb') as f:
    convabuse_user_X_test = pickle.load(f)
with open(f'{pickle_path}convabuse_user_y_train_SMOTE.pkl', 'rb') as g:
    convabuse_user_y_train = pickle.load(g)
with open(f'{pickle_path}convabuse_user_y_test_SMOTE.pkl', 'rb') as h:
    convabuse_user_y_test = pickle.load(h)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}dghs_target_X_train_SMOTE.pkl', 'rb') as e:
    dynamically_generated_hate_speech_target_X_train = pickle.load(e)
with open(f'{pickle_path}dghs_target_X_test_SMOTE.pkl', 'rb') as f:
    dynamically_generated_hate_speech_target_X_test = pickle.load(f)
with open(f'{pickle_path}dghs_target_y_train_SMOTE.pkl', 'rb') as g:
    dynamically_generated_hate_speech_target_y_train = pickle.load(g)
with open(f'{pickle_path}dghs_target_y_test_SMOTE.pkl', 'rb') as h:
    dynamically_generated_hate_speech_target_y_test = pickle.load(h)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}dghs_label_X_train_SMOTE.pkl', 'rb') as e:
    dynamically_generated_hate_speech_label_X_train = pickle.load(e)
with open(f'{pickle_path}dghs_label_X_test_SMOTE.pkl', 'rb') as f:
    dynamically_generated_hate_speech_label_X_test = pickle.load(f)
with open(f'{pickle_path}dghs_label_y_train_SMOTE.pkl', 'rb') as g:
    dynamically_generated_hate_speech_label_y_train = pickle.load(g)
with open(f'{pickle_path}dghs_label_y_test_SMOTE.pkl', 'rb') as h:
    dynamically_generated_hate_speech_label_y_test = pickle.load(h)

# %%
# Open the pickled embeddings
with open(f'{pickle_path}mlma_hate_speech_target_X_train_SMOTE.pkl', 'rb') as e:
    mlma_hate_speech_target_X_train = pickle.load(e)
with open(f'{pickle_path}mlma_hate_speech_target_X_test_SMOTE.pkl', 'rb') as f:
    mlma_hate_speech_target_X_test = pickle.load(f)
with open(f'{pickle_path}mlma_hate_speech_target_y_train_SMOTE.pkl', 'rb') as g:
    mlma_hate_speech_target_y_train = pickle.load(g)
with open(f'{pickle_path}mlma_hate_speech_target_y_test_SMOTE.pkl', 'rb') as h:
    mlma_hate_speech_target_y_test = pickle.load(h)

# %% [markdown]
# # Linear Modeling

# %%
import umap
from sklearn.manifold import TSNE


def linear_modeling(dataset, X_train, X_test, y_train, y_test, target):
  # Perform linear regression on the dataset
  linear_model = LinearRegression()
  linear_model = linear_model.fit(X_train, y_train)
  linear_y_pred = linear_model.predict(X_test)
  linear_rmse = root_mean_squared_error(y_test, linear_y_pred)
  linear_r2 = r2_score(y_test, linear_y_pred)
  print(f"RMSE: {linear_rmse}")
  print(f"R2: {linear_r2}")

  # Get the coefficients for each feature
  linear_coefficients = linear_model.coef_

  # Create a list of column names (assuming they are indexed from 0 to n-1)
  # This handles both pandas DataFrames and NumPy arrays
  if isinstance(X_train, pd.DataFrame):
    column_names = X_train.columns.tolist()
  else:
    column_names = [i for i in range(X_train.shape[1])]

  # Create a dictionary of all coefficients in the original order
  coefficients_data = dict(zip(column_names, linear_coefficients))

  # Sort the feature importances
  linear_columns_sorted = np.argsort(linear_coefficients)[::-1]
  linear_coefficients_sorted = linear_coefficients[linear_columns_sorted]

  # Select the top 10 features and their coefficients (or all if less than 10)
  num_features_to_plot = min(10, len(linear_columns_sorted))
  top_features_indices = linear_columns_sorted[:num_features_to_plot]
  top_coefficients = linear_coefficients_sorted[:num_features_to_plot]

  # Get the names of the top features
  top_feature_names = [column_names[i] for i in top_features_indices]

  # Create a dictionary using the top 10 features and top 10 coefficients
  top_coefficients_data = {
      feature: importance for feature, importance in zip(top_feature_names, top_coefficients)
  }

  # Create a sorted dictionary by value in descending order for output and plotting
  top_coefficients_output = dict(sorted(top_coefficients_data.items(), key=lambda item: item[1], reverse=True))


  # Print the dictionary
  print("Top Coefficients")
  print(top_coefficients_output)


  print("Linear Coefficients")
  print(coefficients_data)

  # Plot the top 10 coefficients as a horizontal bar chart
  plt.figure(figsize=(10, 6))
  # Use the actual integer indices of the top 10 features as labels, sorted by value
  sns.barplot(x=list(top_coefficients_output.values()), y=list(top_coefficients_output.keys()), orient='h', palette='hot')
  plt.xlabel('Coefficient Value')
  plt.ylabel('Feature')
  plt.title(f'Top {num_features_to_plot} Feature Coefficients for {dataset} Linear Model')
  plt.show()


  # Plot the linear model
  plt.figure(figsize=(10, 6))
  scatter = plt.scatter(y_test, linear_y_pred, c=y_test, cmap='hot')
  plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
  plt.xlabel(f"Actual {target}")
  plt.ylabel(f"Predicted {target}")
  plt.title(f"{dataset} Linear Model")
  plt.colorbar(scatter, label=f"{target}")
  plt.show()

  # Use t-sne and color code by the target variable

  # Reduce dimensionality of test data using t-SNE
  tsne_test = TSNE(n_components=2, random_state=42)
  X_test_tsne = tsne_test.fit_transform(X_test)

  # Create a scatter plot
  plt.figure(figsize=(10, 8))
  scatter = plt.scatter(X_test_tsne[:, 0], X_test_tsne[:, 1], c=y_test, cmap='hot', alpha=0.6)
  plt.title(f't-SNE Visualization of {dataset} User Dataset')
  plt.xlabel('t-SNE Component 1')
  plt.ylabel('t-SNE Component 2')
  plt.colorbar(scatter, label=f'{target}')
  plt.show()

  # Use t-sne to plot correct vs incorrect predictions
  # Calculate if predictions are correct (within a tolerance)
  tolerance = 0.5  # Define a tolerance for what is considered "correct"
  correct_predictions = np.abs(linear_y_pred - y_test) <= tolerance

  # Create a scatter plot, coloring by correctness
  plt.figure(figsize=(10, 8))
  scatter = plt.scatter(X_test_tsne[:, 0], X_test_tsne[:, 1], c=correct_predictions, cmap='hot', alpha=0.6)
  plt.title(f't-SNE Visualization of {dataset} Test Data: Correct vs Incorrect Predictions')
  plt.xlabel('t-SNE Component 1')
  plt.ylabel('t-SNE Component 2')
  cbar = plt.colorbar(scatter, ticks=[0, 1])
  cbar.ax.set_yticklabels(['Incorrect', 'Correct'])
  plt.show()

  # Use UMAP and color code by the target variable
  # Reduce dimensionality using UMAP
  reducer = umap.UMAP(random_state=42)
  X_test_umap = reducer.fit_transform(X_test)

  # Create a scatter plot
  plt.figure(figsize=(10, 8))
  scatter = plt.scatter(X_test_umap[:, 0], X_test_umap[:, 1], c=y_test, cmap='hot', alpha=0.6)
  plt.title(f'UMAP Visualization of {dataset} User Dataset')
  plt.xlabel('UMAP Component 1')
  plt.ylabel('UMAP Component 2')
  plt.colorbar(scatter, label=f'{target}')
  plt.show()

  return linear_rmse, linear_r2, coefficients_data, top_coefficients_output, X_test_tsne, X_test_umap

# %%
def get_cluster_indices(tsne_data, X_pos, y_pos, threshold):
  # Investigate the t-SNE cluster at t-SNE Component 1, t-SNE Component 2 coordinates (-25, -50)
  # Define the target coordinates
  target_coordinates = np.array([X_pos, y_pos])

  # Calculate the Euclidean distance from each point to the target coordinates
  distances = np.linalg.norm(tsne_data - target_coordinates, axis=1)

  # Find the indices of the points within the threshold distance
  nearby_indices = np.where(distances <= threshold)[0]

  # Select the corresponding rows from the original X_test dataset
  nearby_points = tsne_data[nearby_indices]

  # Display the nearby points
  print(f"Found {len(nearby_indices)} points near {target_coordinates} with a threshold of {threshold}:")
  display(nearby_points)

  # Display the indices of the nearby points
  print(f"Indices of nearby points:")
  display(nearby_indices)

  return nearby_points, nearby_indices

# %%
# Perform linear regression on the convabuse dataset
convabuse_combined_linear_rmse, convabuse_combined_linear_r2, convabuse_combined_linear_coefficients, convabuse_combined_top_10_coefficients, convabuse_combined_X_test_tsne, convabuse_combined_X_test_umap = linear_modeling("Convabuse combined", convabuse_X_train, convabuse_X_test, convabuse_y_train, convabuse_y_test, "Abuse Level")
# Out:
# RMSE: 1.0958800315856934
# R2: -0.19066309928894043
# Top Coefficients
# {165: np.float32(5.5850844), 382: np.float32(5.0371785), 352: np.float32(4.993483), 117: np.float32(4.897577), 50: np.float32(4.6846495), 310: np.float32(4.5917406), 27: np.float32(4.50368), 90: np.float32(4.18374), 19: np.float32(4.1317205), 71: np.float32(3.8618572)}
# Linear Coefficients
# {0: np.float32(0.78184676), 1: np.float32(-1.7248409), 2: np.float32(0.9638579), 3: np.float32(0.3830366), 4: np.float32(0.19249046), 5: np.float32(0.50550365), 6: np.float32(-3.0805683), 7: np.float32(-0.2991333), 8: np.float32(0.18767178), 9: np.float32(-4.182886), 10: np.float32(1.4249626), 11: np.float32(0.10049552), 12: np.float32(3.3111327), 13: np.float32(1.060818), 14: np.float32(0.6376926), 15: np.float32(-0.7665273), 16: np.float32(-1.8422794), 17: np.float32(-0.4118588), 18: np.float32(-4.233743), 19: np.float32(4.1317205), 20: np.float32(1.027636), 21: np.float32(2.6833887), 22: np.float32(0.024217606), 23: np.float32(2.772391), 24: np.float32(-0.039079905), 25: np.float32(-2.0628161), 26: np.float32(1.3722674), 27: np.float32(4.50368), 28: np.float32(-1.9900172), 29: np.float32(1.9464061), 30: np.float32(0.16456985), 31: np.float32(2.4902456), 32: np.float32(1.0858902), 33: np.float32(-3.8252313), 34: np.float32(-0.96052027), 35: np.float32(-1.7766757), 36: np.float32(2.4971147), 37: np.float32(0.7336746), 38: np.float32(0.0071918964), 39: np.float32(-0.2664808), 40: np.float32(1.2710197), 41: np.float32(0.091635525), 42: np.float32(-1.5353073), 43: np.float32(-2.5119615), 44: np.float32(-1.0782592), 45: np.float32(-1.3051631), 46: np.float32(-1.7935201), 47: np.float32(0.034997463), 48: np.float32(-0.96342266), 49: np.float32(-5.012512), 50: np.float32(4.6846495), 51: np.float32(-0.7085122), 52: np.float32(-0.6348573), 53: np.float32(-0.28742248), 54: np.float32(0.11450175), 55: np.float32(-0.8696313), 56: np.float32(0.7518332), 57: np.float32(2.18476), 58: np.float32(-1.7358961), 59: np.float32(-0.35366857), 60: np.float32(-2.934035), 61: np.float32(0.122703314), 62: np.float32(-2.0978644), 63: np.float32(-3.443233), 64: np.float32(-3.5150914), 65: np.float32(-2.5805607), 66: np.float32(-0.27801913), 67: np.float32(-0.098398864), 68: np.float32(-1.6444166), 69: np.float32(0.055775285), 70: np.float32(0.71756494), 71: np.float32(3.8618572), 72: np.float32(-3.3430884), 73: np.float32(-0.5236842), 74: np.float32(0.4610691), 75: np.float32(-0.13417631), 76: np.float32(-2.2510018), 77: np.float32(-1.1880286), 78: np.float32(1.0824397), 79: np.float32(-1.8002625), 80: np.float32(-0.8070659), 81: np.float32(0.6822933), 82: np.float32(-1.6846275), 83: np.float32(1.7775319), 84: np.float32(-0.010379136), 85: np.float32(-2.205586), 86: np.float32(-1.851728), 87: np.float32(-0.29454315), 88: np.float32(0.71591955), 89: np.float32(-0.3415528), 90: np.float32(4.18374), 91: np.float32(1.0719743), 92: np.float32(-2.225734), 93: np.float32(-4.6204453), 94: np.float32(-2.2827866), 95: np.float32(2.6130953), 96: np.float32(1.9434115), 97: np.float32(-0.9217565), 98: np.float32(0.19208339), 99: np.float32(1.3521491), 100: np.float32(0.24037999), 101: np.float32(-2.0617251), 102: np.float32(-2.5232098), 103: np.float32(-1.0697383), 104: np.float32(0.53673196), 105: np.float32(-0.9302911), 106: np.float32(-1.1744214), 107: np.float32(-1.445038), 108: np.float32(-0.3952163), 109: np.float32(-1.2687705), 110: np.float32(0.506826), 111: np.float32(-1.1386846), 112: np.float32(-1.4756444), 113: np.float32(0.23344374), 114: np.float32(-1.3757645), 115: np.float32(-1.4495466), 116: np.float32(0.5247896), 117: np.float32(4.897577), 118: np.float32(-1.5135176), 119: np.float32(-0.818764), 120: np.float32(0.099677205), 121: np.float32(-3.424543), 122: np.float32(-1.8430121), 123: np.float32(-0.8958278), 124: np.float32(-0.55226046), 125: np.float32(0.118480355), 126: np.float32(-1.5563451), 127: np.float32(4.6253204e-05), 128: np.float32(-1.9242597), 129: np.float32(2.9846807), 130: np.float32(2.718464), 131: np.float32(1.5020069), 132: np.float32(2.202812), 133: np.float32(0.3181615), 134: np.float32(-0.12751853), 135: np.float32(0.10733465), 136: np.float32(-1.3402737), 137: np.float32(2.050119), 138: np.float32(0.55249417), 139: np.float32(0.59078354), 140: np.float32(-1.5232219), 141: np.float32(3.7024875), 142: np.float32(-1.3566358), 1 ...

# %%
# Perform linear regression on the convabuse dataset
convabuse_prev_agent_linear_rmse, convabuse_prev_agent_linear_r2, convabuse_prev_agent_linear_coefficients, convabuse_prev_agent_top_10_coefficients, convabuse_prev_agent_X_test_tsne, convabuse_prev_agent_X_test_umap = linear_modeling("Convabuse prev_agent", convabuse_prev_agent_X_train, convabuse_prev_agent_X_test, convabuse_prev_agent_y_train, convabuse_prev_agent_y_test, "Abuse Level")
# Out:
# RMSE: 1.6007189750671387
# R2: -1.5403470993041992
# Top Coefficients
# {379: np.float32(12.949793), 273: np.float32(9.508967), 268: np.float32(9.120752), 258: np.float32(8.002317), 183: np.float32(7.260851), 372: np.float32(6.8904257), 327: np.float32(6.375191), 291: np.float32(6.0695004), 270: np.float32(6.0093045), 332: np.float32(5.932542)}
# Linear Coefficients
# {0: np.float32(5.253629), 1: np.float32(5.85519), 2: np.float32(2.273502), 3: np.float32(0.4323393), 4: np.float32(-1.740115), 5: np.float32(-2.832739), 6: np.float32(3.7935014), 7: np.float32(-1.1820554), 8: np.float32(3.4853868), 9: np.float32(4.834087), 10: np.float32(-1.0939854), 11: np.float32(1.8408129), 12: np.float32(4.476761), 13: np.float32(-0.32044), 14: np.float32(0.34139124), 15: np.float32(0.97316957), 16: np.float32(0.38854468), 17: np.float32(-1.2180877), 18: np.float32(-2.0340304), 19: np.float32(0.6409044), 20: np.float32(5.7311087), 21: np.float32(0.47832847), 22: np.float32(-0.027633786), 23: np.float32(4.3764524), 24: np.float32(5.3583345), 25: np.float32(-4.7665567), 26: np.float32(3.4955382), 27: np.float32(2.6407337), 28: np.float32(-3.6249306), 29: np.float32(1.1124737), 30: np.float32(3.2008758), 31: np.float32(-6.838523), 32: np.float32(2.9971833), 33: np.float32(0.794082), 34: np.float32(-1.2169274), 35: np.float32(0.7409648), 36: np.float32(-2.8454328), 37: np.float32(1.6129293), 38: np.float32(-1.4986558), 39: np.float32(-5.0209804), 40: np.float32(-3.3928385), 41: np.float32(0.9877257), 42: np.float32(4.087948), 43: np.float32(-4.881285), 44: np.float32(-3.9990392), 45: np.float32(-0.23716182), 46: np.float32(1.3453165), 47: np.float32(-4.141894), 48: np.float32(-0.16332647), 49: np.float32(3.0765824), 50: np.float32(4.396755), 51: np.float32(-3.7567172), 52: np.float32(0.80231476), 53: np.float32(-0.8790517), 54: np.float32(-0.0023729205), 55: np.float32(-0.053513825), 56: np.float32(1.3446602), 57: np.float32(1.2596192), 58: np.float32(-1.2701828), 59: np.float32(-0.05026549), 60: np.float32(1.6656256), 61: np.float32(4.3792534), 62: np.float32(-0.40106964), 63: np.float32(-0.4041293), 64: np.float32(1.4927249), 65: np.float32(0.44159937), 66: np.float32(-2.518336), 67: np.float32(4.711377), 68: np.float32(4.1818776), 69: np.float32(2.5174093), 70: np.float32(1.5093195), 71: np.float32(-2.333886), 72: np.float32(0.7960049), 73: np.float32(-1.4202447), 74: np.float32(4.6607094), 75: np.float32(0.92904997), 76: np.float32(0.5312217), 77: np.float32(1.704153), 78: np.float32(-2.3583915), 79: np.float32(0.39388967), 80: np.float32(-1.5397623), 81: np.float32(-0.92981637), 82: np.float32(2.9457679), 83: np.float32(0.075225115), 84: np.float32(1.6395174), 85: np.float32(-3.294168), 86: np.float32(-7.156639), 87: np.float32(0.30661494), 88: np.float32(-3.1333547), 89: np.float32(3.3622336), 90: np.float32(4.6799912), 91: np.float32(5.70025), 92: np.float32(0.7818624), 93: np.float32(-1.8394128), 94: np.float32(-5.268365), 95: np.float32(-4.4230475), 96: np.float32(0.8789409), 97: np.float32(-1.3393002), 98: np.float32(-0.036361396), 99: np.float32(5.305007), 100: np.float32(1.2630644), 101: np.float32(3.5002244), 102: np.float32(-4.9682264), 103: np.float32(-2.2912645), 104: np.float32(0.95991445), 105: np.float32(0.26714587), 106: np.float32(-1.0474273), 107: np.float32(5.3990097), 108: np.float32(0.30351073), 109: np.float32(-0.03857097), 110: np.float32(3.15285), 111: np.float32(4.6312933), 112: np.float32(-4.608633), 113: np.float32(-0.92912513), 114: np.float32(5.767521), 115: np.float32(3.0518827), 116: np.float32(0.18177257), 117: np.float32(1.5342162), 118: np.float32(-6.108353), 119: np.float32(3.391317), 120: np.float32(3.593874), 121: np.float32(-4.2371655), 122: np.float32(0.48250982), 123: np.float32(2.461127), 124: np.float32(0.59622395), 125: np.float32(-5.3414507), 126: np.float32(-2.102114), 127: np.float32(9.059906e-06), 128: np.float32(-0.8382238), 129: np.float32(0.31924915), 130: np.float32(0.6505345), 131: np.float32(4.4184437), 132: np.float32(-5.4304295), 133: np.float32(2.809111), 134: np.float32(-4.065641), 135: np.float32(-1.2913948), 136: np.float32(-1.6100943), 137: np.float32(-0.49374077), 138: np.float32(-3.6699142), 139: np.float32(-2.3492374), 140: np.float32(-5.7763767), 141: np.float32(3.2281747), 142: np.float32(-2.0728881), 143: np.float32(-0.97202975), 144: np.flo ...

# %%
# Perform linear regression on the convabuse dataset
convabuse_prev_user_linear_rmse, convabuse_prev_user_linear_r2, convabuse_prev_user_linear_coefficients, convabuse_prev_user_top_10_coefficients, convabuse_prev_user_X_test_tsne, convabuse_prev_user_X_test_umap = linear_modeling("Convabuse prev_user", convabuse_prev_user_X_train, convabuse_prev_user_X_test, convabuse_prev_user_y_train, convabuse_prev_user_y_test, "abuse_level")
# Out:
# RMSE: 1.5559806823730469
# R2: -1.400331974029541
# Top Coefficients
# {130: np.float32(5.2098746), 169: np.float32(3.926147), 219: np.float32(3.825575), 52: np.float32(3.669819), 322: np.float32(3.5941634), 338: np.float32(3.5293107), 255: np.float32(3.4959068), 237: np.float32(3.4654596), 134: np.float32(3.18545), 273: np.float32(3.1038313)}
# Linear Coefficients
# {0: np.float32(-0.6975128), 1: np.float32(-1.5159559), 2: np.float32(-1.9255601), 3: np.float32(1.2900316), 4: np.float32(-0.45728034), 5: np.float32(-2.1496758), 6: np.float32(2.220152), 7: np.float32(-2.660801), 8: np.float32(-4.3322635), 9: np.float32(-3.0571265), 10: np.float32(0.8022287), 11: np.float32(1.850688), 12: np.float32(0.1230143), 13: np.float32(-3.8022776), 14: np.float32(-1.5019412), 15: np.float32(-3.2224054), 16: np.float32(-1.3095484), 17: np.float32(-0.015007138), 18: np.float32(0.9540701), 19: np.float32(1.8129642), 20: np.float32(-0.55193144), 21: np.float32(-1.9243523), 22: np.float32(2.1026413), 23: np.float32(-1.522465), 24: np.float32(-4.823444), 25: np.float32(-2.122745), 26: np.float32(0.041645765), 27: np.float32(1.2914308), 28: np.float32(-0.9816562), 29: np.float32(-2.53218), 30: np.float32(-1.8058288), 31: np.float32(-1.3885981), 32: np.float32(-0.042507112), 33: np.float32(0.5471661), 34: np.float32(0.46509355), 35: np.float32(0.18470499), 36: np.float32(-1.6364219), 37: np.float32(0.80053324), 38: np.float32(0.7530966), 39: np.float32(0.5267463), 40: np.float32(0.1979137), 41: np.float32(-0.23560846), 42: np.float32(1.3142533), 43: np.float32(2.3680341), 44: np.float32(-3.3392665), 45: np.float32(2.0684166), 46: np.float32(-0.286232), 47: np.float32(-1.4376037), 48: np.float32(0.67526525), 49: np.float32(-4.8714843), 50: np.float32(-2.1161208), 51: np.float32(-0.44386053), 52: np.float32(3.669819), 53: np.float32(0.17019022), 54: np.float32(1.5588189), 55: np.float32(-2.651651), 56: np.float32(-0.8751404), 57: np.float32(1.0126783), 58: np.float32(0.7632062), 59: np.float32(-3.225316), 60: np.float32(-2.59121), 61: np.float32(0.032779038), 62: np.float32(-2.3556461), 63: np.float32(-1.4610558), 64: np.float32(-0.768619), 65: np.float32(-4.2065187), 66: np.float32(-1.1035317), 67: np.float32(0.20047452), 68: np.float32(-2.5519097), 69: np.float32(-2.3322153), 70: np.float32(0.89344096), 71: np.float32(-0.44894955), 72: np.float32(-0.5712987), 73: np.float32(-2.9966047), 74: np.float32(1.1108944), 75: np.float32(-3.2242832), 76: np.float32(-1.430969), 77: np.float32(-0.6725917), 78: np.float32(2.4846647), 79: np.float32(-5.16168), 80: np.float32(-0.747343), 81: np.float32(-1.367232), 82: np.float32(-3.9419281), 83: np.float32(0.41643143), 84: np.float32(-0.1526221), 85: np.float32(-3.492554), 86: np.float32(-0.5607663), 87: np.float32(-1.848708), 88: np.float32(-0.47362083), 89: np.float32(0.5516759), 90: np.float32(-0.30533254), 91: np.float32(1.0738399), 92: np.float32(0.33381045), 93: np.float32(-1.1716716), 94: np.float32(-1.0750736), 95: np.float32(1.2674218), 96: np.float32(-0.69239104), 97: np.float32(1.3784237), 98: np.float32(-1.2788395), 99: np.float32(-0.011259675), 100: np.float32(2.0505824), 101: np.float32(-1.9155664), 102: np.float32(-2.3619914), 103: np.float32(-1.389597), 104: np.float32(-0.79865634), 105: np.float32(0.10197964), 106: np.float32(1.4303882), 107: np.float32(-3.334252), 108: np.float32(2.2882233), 109: np.float32(0.49288383), 110: np.float32(-0.46058756), 111: np.float32(-3.0306597), 112: np.float32(0.60999596), 113: np.float32(-0.106842786), 114: np.float32(-0.54227644), 115: np.float32(-1.8709831), 116: np.float32(-1.2263377), 117: np.float32(-0.72544277), 118: np.float32(1.9666206), 119: np.float32(-0.17454547), 120: np.float32(1.0518031), 121: np.float32(-0.76311755), 122: np.float32(1.0777912), 123: np.float32(-1.5639763), 124: np.float32(-1.2776475), 125: np.float32(-2.3961463), 126: np.float32(-0.89159596), 127: np.float32(-1.4305115e-06), 128: np.float32(0.38235396), 129: np.float32(-1.1024396), 130: np.float32(5.2098746), 131: np.float32(-0.94325495), 132: np.float32(-0.08816409), 133: np.float32(0.9157163), 134: np.float32(3.18545), 135: np.float32(1.4886227), 136: np.float32(0.5919075), 137: np.float32(-0.21853378), 138: np.float32(1.1727548), 139: np.float32(-3.201231), 140: np.float32(1.8448792), 141: np.float32(-2.4271646), 142: np.float32(-0.640163 ...

# %%
# Perform linear regression on the convabuse dataset
convabuse_agent_linear_rmse, convabuse_agent_linear_r2, convabuse_agent_linear_coefficients, convabuse_agent_top_10_coefficients, convabuse_agent_X_test_tsne, convabuse_agent_X_test_umap = linear_modeling("Convabuse agent", convabuse_agent_X_train, convabuse_agent_X_test, convabuse_agent_y_train, convabuse_agent_y_test, "Abuse Level")
# Out:
# RMSE: 1.6051511764526367
# R2: -1.5544345378875732
# Top Coefficients
# {185: np.float32(9.14351), 3: np.float32(8.625567), 279: np.float32(7.850523), 52: np.float32(7.569348), 344: np.float32(7.4957476), 20: np.float32(7.414669), 208: np.float32(7.1870403), 240: np.float32(6.5778694), 130: np.float32(6.4490476), 112: np.float32(6.441336)}
# Linear Coefficients
# {0: np.float32(-0.72618026), 1: np.float32(0.72120565), 2: np.float32(3.206022), 3: np.float32(8.625567), 4: np.float32(-1.7170618), 5: np.float32(1.4350091), 6: np.float32(-5.009857), 7: np.float32(2.353721), 8: np.float32(3.2067933), 9: np.float32(1.8610768), 10: np.float32(-1.6547583), 11: np.float32(3.2683847), 12: np.float32(-0.023160994), 13: np.float32(4.026809), 14: np.float32(-1.4426502), 15: np.float32(-6.3099256), 16: np.float32(-2.1258788), 17: np.float32(-3.3638415), 18: np.float32(-4.0456204), 19: np.float32(-3.6568136), 20: np.float32(7.414669), 21: np.float32(0.708853), 22: np.float32(4.529744), 23: np.float32(1.0579242), 24: np.float32(1.2279227), 25: np.float32(-0.7356956), 26: np.float32(-4.496173), 27: np.float32(2.7662377), 28: np.float32(0.06784612), 29: np.float32(-4.061829), 30: np.float32(-2.7688777), 31: np.float32(1.1763791), 32: np.float32(2.555759), 33: np.float32(-2.4355125), 34: np.float32(-2.923662), 35: np.float32(-0.8253131), 36: np.float32(-4.405392), 37: np.float32(-4.162681), 38: np.float32(-1.2799239), 39: np.float32(4.8752904), 40: np.float32(1.6643381), 41: np.float32(-4.427484), 42: np.float32(-0.9794953), 43: np.float32(-4.4495554), 44: np.float32(2.0234873), 45: np.float32(-0.8318398), 46: np.float32(-4.2039785), 47: np.float32(-5.9143476), 48: np.float32(-2.2297502), 49: np.float32(-1.048125), 50: np.float32(1.9674375), 51: np.float32(-3.0577), 52: np.float32(7.569348), 53: np.float32(-0.53117406), 54: np.float32(6.116115), 55: np.float32(-4.6783667), 56: np.float32(0.37904328), 57: np.float32(4.0353384), 58: np.float32(0.0066803694), 59: np.float32(-0.1233083), 60: np.float32(-1.8380142), 61: np.float32(5.2601233), 62: np.float32(3.2713315), 63: np.float32(-1.0088576), 64: np.float32(-1.3383226), 65: np.float32(-4.8607283), 66: np.float32(-1.2114034), 67: np.float32(-2.652235), 68: np.float32(3.4369938), 69: np.float32(2.0124304), 70: np.float32(1.0971212), 71: np.float32(-2.8866181), 72: np.float32(-4.9026704), 73: np.float32(1.4825829), 74: np.float32(2.9535418), 75: np.float32(-0.31685853), 76: np.float32(-5.052653), 77: np.float32(0.43418717), 78: np.float32(0.7331093), 79: np.float32(3.9594836), 80: np.float32(-1.6968505), 81: np.float32(2.847394), 82: np.float32(2.07757), 83: np.float32(-0.6620013), 84: np.float32(2.668188), 85: np.float32(-4.3578763), 86: np.float32(-3.6076074), 87: np.float32(-6.7823477), 88: np.float32(0.00094407797), 89: np.float32(-2.9972863), 90: np.float32(-0.32675394), 91: np.float32(6.416241), 92: np.float32(0.6365865), 93: np.float32(-0.112271786), 94: np.float32(-2.419423), 95: np.float32(-2.1994996), 96: np.float32(-2.1411033), 97: np.float32(-3.5778399), 98: np.float32(4.4859533), 99: np.float32(-0.35255325), 100: np.float32(4.2190833), 101: np.float32(-6.2009816), 102: np.float32(3.4775708), 103: np.float32(-3.2933877), 104: np.float32(4.153934), 105: np.float32(1.6357495), 106: np.float32(1.6024324), 107: np.float32(0.35970795), 108: np.float32(-0.58977413), 109: np.float32(1.5559276), 110: np.float32(2.3122501), 111: np.float32(1.6955633), 112: np.float32(6.441336), 113: np.float32(-1.1852953), 114: np.float32(1.0367824), 115: np.float32(3.63634), 116: np.float32(2.2419505), 117: np.float32(-3.845269), 118: np.float32(0.54527116), 119: np.float32(-4.467708), 120: np.float32(0.4436522), 121: np.float32(1.2491182), 122: np.float32(-3.966516), 123: np.float32(4.4205914), 124: np.float32(-0.79470813), 125: np.float32(0.64355886), 126: np.float32(-1.2717948), 127: np.float32(3.8146973e-06), 128: np.float32(4.67073), 129: np.float32(-0.84265715), 130: np.float32(6.4490476), 131: np.float32(-5.514675), 132: np.float32(-3.0570908), 133: np.float32(-0.68833053), 134: np.float32(3.2142482), 135: np.float32(-1.9324019), 136: np.float32(-4.056168), 137: np.float32(2.5857983), 138: np.float32(-2.4210596), 139: np.float32(-3.0911088), 140: np.float32(2.2574356), 141: np.float32(3.3464305), 142: np.float32(2.8582451), 143: np.float32(3.2555094), 144: np.float ...

# %%
# Perform linear regression on the convabuse dataset
convabuse_user_linear_rmse, convabuse_user_linear_r2, convabuse_user_linear_coefficients, convabuse_user_top_10_coefficients, convabuse_user_X_test_tsne, convabuse_user_X_test_umap = linear_modeling("Convabuse user", convabuse_user_X_train, convabuse_user_X_test, convabuse_user_y_train, convabuse_user_y_test, "Abuse Level")
# Out:
# RMSE: 0.9060830473899841
# R2: 0.18604779243469238
# Top Coefficients
# {157: np.float32(5.50272), 117: np.float32(3.2238429), 249: np.float32(3.1601136), 276: np.float32(2.8943992), 210: np.float32(2.8893518), 104: np.float32(2.8174899), 227: np.float32(2.7276466), 224: np.float32(2.6031327), 316: np.float32(2.5606742), 182: np.float32(2.5301893)}
# Linear Coefficients
# {0: np.float32(-1.0281126), 1: np.float32(0.47622895), 2: np.float32(2.2835937), 3: np.float32(0.271613), 4: np.float32(-0.6339907), 5: np.float32(1.2802663), 6: np.float32(0.52861273), 7: np.float32(1.3560458), 8: np.float32(0.78398275), 9: np.float32(0.60469866), 10: np.float32(0.92332053), 11: np.float32(-0.7018593), 12: np.float32(1.3592908), 13: np.float32(0.6385925), 14: np.float32(-0.7624898), 15: np.float32(0.9012847), 16: np.float32(1.3965201), 17: np.float32(0.18366647), 18: np.float32(-0.40027434), 19: np.float32(1.4412687), 20: np.float32(1.233822), 21: np.float32(1.6777486), 22: np.float32(0.2888385), 23: np.float32(-0.07308503), 24: np.float32(0.29031482), 25: np.float32(-1.1851466), 26: np.float32(0.4857548), 27: np.float32(1.368784), 28: np.float32(-0.44832295), 29: np.float32(2.2127192), 30: np.float32(0.70229244), 31: np.float32(-0.377586), 32: np.float32(1.2377865), 33: np.float32(-0.79051316), 34: np.float32(-0.28042608), 35: np.float32(-0.10776988), 36: np.float32(0.9402748), 37: np.float32(0.34398246), 38: np.float32(-0.08054012), 39: np.float32(0.4072259), 40: np.float32(1.2892851), 41: np.float32(0.32157016), 42: np.float32(0.97599673), 43: np.float32(0.3228787), 44: np.float32(-1.5956917), 45: np.float32(-0.032328542), 46: np.float32(0.34017226), 47: np.float32(0.23509014), 48: np.float32(-0.1319506), 49: np.float32(-2.299645), 50: np.float32(0.24100077), 51: np.float32(0.8094414), 52: np.float32(0.016102657), 53: np.float32(0.67081016), 54: np.float32(0.12902579), 55: np.float32(-2.5876436), 56: np.float32(-0.8712567), 57: np.float32(-0.35076892), 58: np.float32(-2.5041835), 59: np.float32(0.96745753), 60: np.float32(-0.78737545), 61: np.float32(-0.8034796), 62: np.float32(-0.23780102), 63: np.float32(0.008238494), 64: np.float32(-0.3209652), 65: np.float32(-2.4291892), 66: np.float32(0.8339855), 67: np.float32(-0.38125423), 68: np.float32(0.4523745), 69: np.float32(1.0589589), 70: np.float32(-0.2320783), 71: np.float32(1.0853498), 72: np.float32(0.017136458), 73: np.float32(0.03153777), 74: np.float32(-0.5218967), 75: np.float32(1.8618326), 76: np.float32(0.72254246), 77: np.float32(-1.5724177), 78: np.float32(-0.016228274), 79: np.float32(2.0158231), 80: np.float32(0.41598478), 81: np.float32(1.7365421), 82: np.float32(1.3323759), 83: np.float32(1.3219097), 84: np.float32(-2.0936518), 85: np.float32(-1.6761543), 86: np.float32(-1.122051), 87: np.float32(-0.06141347), 88: np.float32(1.1388865), 89: np.float32(0.017131545), 90: np.float32(1.5936165), 91: np.float32(-0.29181838), 92: np.float32(-1.544719), 93: np.float32(-0.07556181), 94: np.float32(-0.855367), 95: np.float32(1.8005633), 96: np.float32(-1.5524347), 97: np.float32(-0.43286592), 98: np.float32(-0.052184187), 99: np.float32(0.6685278), 100: np.float32(0.6746421), 101: np.float32(-1.8730025), 102: np.float32(-0.5002581), 103: np.float32(-0.3456274), 104: np.float32(2.8174899), 105: np.float32(-1.9969858), 106: np.float32(-0.95569843), 107: np.float32(1.1220394), 108: np.float32(-0.092540234), 109: np.float32(1.0330703), 110: np.float32(-0.02692607), 111: np.float32(-0.9814584), 112: np.float32(-0.84472317), 113: np.float32(0.15597491), 114: np.float32(1.2602938), 115: np.float32(-0.8209872), 116: np.float32(0.8011189), 117: np.float32(3.2238429), 118: np.float32(-0.5602527), 119: np.float32(0.7098793), 120: np.float32(0.82774067), 121: np.float32(-0.060143568), 122: np.float32(0.129711), 123: np.float32(1.9830122), 124: np.float32(1.0138226), 125: np.float32(-1.4895078), 126: np.float32(0.18918821), 127: np.float32(-7.748604e-07), 128: np.float32(-1.9698285), 129: np.float32(0.43823102), 130: np.float32(-1.9164435), 131: np.float32(-0.48785606), 132: np.float32(-0.13164908), 133: np.float32(-2.041617), 134: np.float32(-1.2319452), 135: np.float32(1.7183326), 136: np.float32(0.083869815), 137: np.float32(1.925713), 138: np.float32(-0.43509576), 139: np.float32(0.9444268), 140: np.float32(-1.9479082), 141: np.float32(1.0452408), 142: np.floa ...

# %%
# Perform linear regression on the dynamically generated hate speech dataset
dynamically_generated_hate_speech_target_linear_rmse, dynamically_generated_hate_speech_target_linear_r2, dynamically_generated_hate_speech_target_linear_coefficients, dynamically_generated_hate_speech_target_top_10_coefficients, dynamically_generated_hate_speech_target_target_X_test_tsne, dynamically_generated_hate_speech_target_X_test_umap = linear_modeling("Dynamically Generated Hate Speech target", dynamically_generated_hate_speech_target_X_train, dynamically_generated_hate_speech_target_X_test, dynamically_generated_hate_speech_target_y_train, dynamically_generated_hate_speech_target_y_test, "Target Group")
# Out:
# RMSE: 0.45467665791511536
# R2: -0.12066280841827393
# Top Coefficients
# {268: np.float32(0.8433245), 224: np.float32(0.8181921), 157: np.float32(0.73912436), 312: np.float32(0.6810423), 190: np.float32(0.5916444), 20: np.float32(0.5750921), 218: np.float32(0.5719184), 369: np.float32(0.5551429), 145: np.float32(0.52567875), 245: np.float32(0.48555964)}
# Linear Coefficients
# {0: np.float32(-0.23720637), 1: np.float32(-0.43264133), 2: np.float32(-0.4024073), 3: np.float32(-0.456365), 4: np.float32(0.068388745), 5: np.float32(-0.3071425), 6: np.float32(-0.17384246), 7: np.float32(-0.2296142), 8: np.float32(0.17091867), 9: np.float32(0.3946833), 10: np.float32(-0.65662634), 11: np.float32(0.15729322), 12: np.float32(-0.23645538), 13: np.float32(1.1533499e-05), 14: np.float32(-0.893033), 15: np.float32(-0.2666943), 16: np.float32(-0.17917672), 17: np.float32(-0.21186036), 18: np.float32(-0.51549286), 19: np.float32(-0.21179444), 20: np.float32(0.5750921), 21: np.float32(0.27393323), 22: np.float32(-0.092933506), 23: np.float32(0.01633732), 24: np.float32(0.15856266), 25: np.float32(0.12299365), 26: np.float32(-0.06866774), 27: np.float32(0.022852927), 28: np.float32(-0.029072702), 29: np.float32(-0.28925115), 30: np.float32(-0.4971393), 31: np.float32(0.2956803), 32: np.float32(-0.34924108), 33: np.float32(0.29014108), 34: np.float32(0.029542223), 35: np.float32(0.14010401), 36: np.float32(-0.6810461), 37: np.float32(-0.96104294), 38: np.float32(-0.39302683), 39: np.float32(0.2591951), 40: np.float32(0.4581074), 41: np.float32(0.08207539), 42: np.float32(-0.35190535), 43: np.float32(0.057079196), 44: np.float32(-0.5972078), 45: np.float32(-0.049708724), 46: np.float32(0.20536715), 47: np.float32(0.2577091), 48: np.float32(-0.5668502), 49: np.float32(-0.20050359), 50: np.float32(0.36178955), 51: np.float32(-0.35505185), 52: np.float32(0.37423044), 53: np.float32(-0.22820464), 54: np.float32(0.018145233), 55: np.float32(-0.33118072), 56: np.float32(-0.24996753), 57: np.float32(0.09218466), 58: np.float32(-0.2528638), 59: np.float32(-0.41783217), 60: np.float32(0.3200605), 61: np.float32(-0.16011451), 62: np.float32(-0.11526445), 63: np.float32(0.054582298), 64: np.float32(0.28794768), 65: np.float32(0.025772363), 66: np.float32(-0.21091908), 67: np.float32(-0.20288527), 68: np.float32(-0.4286256), 69: np.float32(-0.15445477), 70: np.float32(0.45814487), 71: np.float32(-0.40765548), 72: np.float32(-0.46636948), 73: np.float32(-0.38882685), 74: np.float32(-0.8649759), 75: np.float32(0.39387468), 76: np.float32(-0.5177843), 77: np.float32(-0.4176271), 78: np.float32(-0.24871972), 79: np.float32(0.021038778), 80: np.float32(-0.051440276), 81: np.float32(0.14889474), 82: np.float32(-0.3888372), 83: np.float32(0.28579262), 84: np.float32(-0.23894906), 85: np.float32(-0.3428697), 86: np.float32(-0.31826), 87: np.float32(-0.3419637), 88: np.float32(-0.2023792), 89: np.float32(0.26359892), 90: np.float32(-0.037573367), 91: np.float32(0.07154476), 92: np.float32(-0.04493752), 93: np.float32(-0.49387294), 94: np.float32(-0.098703966), 95: np.float32(-0.57785237), 96: np.float32(-0.5949818), 97: np.float32(-0.24933791), 98: np.float32(0.12530428), 99: np.float32(-0.6266664), 100: np.float32(-0.3953864), 101: np.float32(-0.6213682), 102: np.float32(-0.021102168), 103: np.float32(-0.0730665), 104: np.float32(0.34285405), 105: np.float32(0.07148333), 106: np.float32(-0.23650134), 107: np.float32(-0.097412705), 108: np.float32(-0.50582063), 109: np.float32(-0.299244), 110: np.float32(0.06779799), 111: np.float32(-0.3961649), 112: np.float32(0.14796337), 113: np.float32(-0.30144), 114: np.float32(-0.15013814), 115: np.float32(-0.2359611), 116: np.float32(-0.300361), 117: np.float32(-0.24076009), 118: np.float32(-0.5671334), 119: np.float32(0.07720211), 120: np.float32(0.11423293), 121: np.float32(-0.04702587), 122: np.float32(-0.534811), 123: np.float32(-0.3314519), 124: np.float32(-0.051807676), 125: np.float32(-0.3842814), 126: np.float32(-0.103215545), 127: np.float32(-8.940697e-08), 128: np.float32(0.106296256), 129: np.float32(-0.013333067), 130: np.float32(-0.51796305), 131: np.float32(0.13333398), 132: np.float32(-0.10304204), 133: np.float32(-0.7199193), 134: np.float32(-0.25476035), 135: np.float32(0.10831186), 136: np.float32(0.20829278), 137: np.float32(-0.0014104247), 138: np.float32(-0.12865847), 139: np.fl ...

# %%
# Perform linear regression on the dynamically generated hate speech dataset
dynamically_generated_hate_speech_label_linear_rmse, dynamically_generated_hate_speech_label_linear_r2, dynamically_generated_hate_speech_label_linear_coefficients, dynamically_generated_hate_speech_label_top_10_coefficients, dynamically_generated_hate_speech_label_X_test_tsne, dynamically_generated_hate_speech_label_X_test_umap = linear_modeling("Dynamically Generated Hate Speech label", dynamically_generated_hate_speech_label_X_train, dynamically_generated_hate_speech_label_X_test, dynamically_generated_hate_speech_label_y_train, dynamically_generated_hate_speech_label_y_test, "Label")
# Out:
# RMSE: 0.43930814824468317
# R2: 0.22386582648352105
# Top Coefficients
# {206: np.float32(0.9347662), 99: np.float32(0.7496796), 157: np.float32(0.7167652), 89: np.float32(0.7091411), 112: np.float32(0.69187343), 27: np.float32(0.6699721), 69: np.float32(0.6583604), 227: np.float32(0.6449741), 8: np.float32(0.5997847), 58: np.float32(0.5696524)}
# Linear Coefficients
# {0: np.float32(-0.20349869), 1: np.float32(0.2109878), 2: np.float32(-0.3860342), 3: np.float32(-0.31182176), 4: np.float32(0.1965406), 5: np.float32(0.07986719), 6: np.float32(0.36267063), 7: np.float32(-0.73386014), 8: np.float32(0.5997847), 9: np.float32(0.31077275), 10: np.float32(0.13469583), 11: np.float32(0.02287975), 12: np.float32(-0.14684251), 13: np.float32(0.16833079), 14: np.float32(-0.22270916), 15: np.float32(0.23429358), 16: np.float32(0.1308761), 17: np.float32(0.2906835), 18: np.float32(0.35720754), 19: np.float32(-0.24231705), 20: np.float32(0.04682091), 21: np.float32(0.2339209), 22: np.float32(0.040975526), 23: np.float32(-0.0812864), 24: np.float32(-0.0708946), 25: np.float32(-0.07597554), 26: np.float32(0.41919795), 27: np.float32(0.6699721), 28: np.float32(0.04440456), 29: np.float32(-0.0657551), 30: np.float32(0.3299331), 31: np.float32(0.3145012), 32: np.float32(-0.35551947), 33: np.float32(0.2540331), 34: np.float32(-0.04750374), 35: np.float32(-0.05665216), 36: np.float32(0.07622835), 37: np.float32(-0.107718036), 38: np.float32(-0.26258937), 39: np.float32(0.49377915), 40: np.float32(0.115210116), 41: np.float32(0.18307123), 42: np.float32(0.13343477), 43: np.float32(0.24628282), 44: np.float32(0.040414006), 45: np.float32(0.40355116), 46: np.float32(0.5078692), 47: np.float32(-0.21385062), 48: np.float32(-0.22256622), 49: np.float32(-0.21417455), 50: np.float32(0.29246205), 51: np.float32(-0.20087156), 52: np.float32(0.052824095), 53: np.float32(0.012203522), 54: np.float32(0.43569234), 55: np.float32(-0.21793903), 56: np.float32(0.115105376), 57: np.float32(0.013735384), 58: np.float32(0.5696524), 59: np.float32(-0.25256968), 60: np.float32(0.020808846), 61: np.float32(0.41759247), 62: np.float32(0.1408297), 63: np.float32(0.315084), 64: np.float32(0.3163767), 65: np.float32(-0.3220368), 66: np.float32(0.33931175), 67: np.float32(0.10527121), 68: np.float32(0.041095793), 69: np.float32(0.6583604), 70: np.float32(0.21071573), 71: np.float32(-0.49892002), 72: np.float32(-0.74957645), 73: np.float32(0.064636245), 74: np.float32(0.3160221), 75: np.float32(-0.7161635), 76: np.float32(-0.03584171), 77: np.float32(-0.52189034), 78: np.float32(0.19713691), 79: np.float32(0.006974399), 80: np.float32(0.2559411), 81: np.float32(0.028521925), 82: np.float32(0.017996904), 83: np.float32(0.43921292), 84: np.float32(0.0689245), 85: np.float32(0.1385934), 86: np.float32(-0.14553002), 87: np.float32(0.15247905), 88: np.float32(-0.24114865), 89: np.float32(0.7091411), 90: np.float32(0.27902365), 91: np.float32(0.05673504), 92: np.float32(0.14864704), 93: np.float32(-0.40293345), 94: np.float32(0.09109513), 95: np.float32(0.28391048), 96: np.float32(-0.60203177), 97: np.float32(0.5397412), 98: np.float32(-0.02777854), 99: np.float32(0.7496796), 100: np.float32(0.04262993), 101: np.float32(-0.35719246), 102: np.float32(0.5151069), 103: np.float32(-0.036177486), 104: np.float32(-0.03374578), 105: np.float32(0.2963355), 106: np.float32(-0.21447891), 107: np.float32(-0.05269195), 108: np.float32(-0.40344417), 109: np.float32(-0.11893045), 110: np.float32(-0.17285296), 111: np.float32(-0.16645241), 112: np.float32(0.69187343), 113: np.float32(-0.2785436), 114: np.float32(-0.37213328), 115: np.float32(-0.6628712), 116: np.float32(-0.28696522), 117: np.float32(0.14543416), 118: np.float32(0.06194129), 119: np.float32(-0.4449085), 120: np.float32(-0.007808244), 121: np.float32(0.061120413), 122: np.float32(-0.11175729), 123: np.float32(-0.5779934), 124: np.float32(0.0061827023), 125: np.float32(-0.44422495), 126: np.float32(0.13256074), 127: np.float32(1.1920929e-07), 128: np.float32(-0.25672686), 129: np.float32(0.3517868), 130: np.float32(-0.509754), 131: np.float32(-0.102603436), 132: np.float32(0.24400015), 133: np.float32(-0.24527445), 134: np.float32(-0.43912962), 135: np.float32(-0.10066632), 136: np.float32(0.3312732), 137: np.float32(-0.24512167), 138: np.float32(-0.50353473), 139: np.float32(0.16918762), 140: np ...

# %%
# Perform linear regression on the convabuse dataset
mlma_hate_speech_target_linear_rmse, mlma_hate_speech_target_linear_r2, mlma_hate_speech_target_linear_coefficients, mlma_hate_speech_target_top_10_coefficients, mlma_hate_speech_target_X_test_tsne, mlma_hate_speech_target_X_test_umap = linear_modeling("MLMA Hate Speech target", mlma_hate_speech_target_X_train, mlma_hate_speech_target_X_test, mlma_hate_speech_target_y_train, mlma_hate_speech_target_y_test, "HOF")
# Out:
# RMSE: 0.8073389530181885
# R2: -0.8379566669464111
# Top Coefficients
# {283: np.float32(3.896449), 186: np.float32(3.1817932), 299: np.float32(2.913108), 343: np.float32(2.7565024), 6: np.float32(2.623225), 363: np.float32(2.6165504), 53: np.float32(2.5783615), 181: np.float32(2.5694704), 8: np.float32(2.4021087), 70: np.float32(2.3921635)}
# Linear Coefficients
# {0: np.float32(-1.0401444), 1: np.float32(-0.7909471), 2: np.float32(-1.0219293), 3: np.float32(-1.3713529), 4: np.float32(0.11203319), 5: np.float32(-0.7869394), 6: np.float32(2.623225), 7: np.float32(-1.2186176), 8: np.float32(2.4021087), 9: np.float32(-1.0334681), 10: np.float32(0.78832054), 11: np.float32(-0.82757455), 12: np.float32(-2.2824621), 13: np.float32(0.92407537), 14: np.float32(0.92178), 15: np.float32(-0.1004014), 16: np.float32(-0.5632777), 17: np.float32(-1.0333065), 18: np.float32(-2.9157815), 19: np.float32(-0.97729015), 20: np.float32(-0.018094301), 21: np.float32(0.9364881), 22: np.float32(1.4517808), 23: np.float32(-0.8894489), 24: np.float32(0.7257651), 25: np.float32(-1.815484), 26: np.float32(0.64742553), 27: np.float32(-0.028304815), 28: np.float32(0.53889704), 29: np.float32(-0.8912917), 30: np.float32(-0.57124543), 31: np.float32(1.0008698), 32: np.float32(1.5068334), 33: np.float32(1.6213913), 34: np.float32(1.2979295), 35: np.float32(0.9133409), 36: np.float32(0.4041264), 37: np.float32(-3.3461485), 38: np.float32(-0.5160428), 39: np.float32(0.1043331), 40: np.float32(1.1827977), 41: np.float32(-0.18882966), 42: np.float32(1.6143298), 43: np.float32(0.13912846), 44: np.float32(0.2625204), 45: np.float32(0.40332916), 46: np.float32(-0.99942505), 47: np.float32(0.3099321), 48: np.float32(-1.4526131), 49: np.float32(-0.39444506), 50: np.float32(-0.18866451), 51: np.float32(-1.040633), 52: np.float32(1.3595889), 53: np.float32(2.5783615), 54: np.float32(1.2756629), 55: np.float32(-2.2073226), 56: np.float32(-0.19622725), 57: np.float32(-1.2062889), 58: np.float32(1.5284142), 59: np.float32(1.5153393), 60: np.float32(0.64296246), 61: np.float32(0.49861592), 62: np.float32(-1.0114014), 63: np.float32(1.0676022), 64: np.float32(1.8686657), 65: np.float32(1.3608992), 66: np.float32(0.19803569), 67: np.float32(1.8372307), 68: np.float32(-1.0019852), 69: np.float32(-0.45168623), 70: np.float32(2.3921635), 71: np.float32(-0.33862215), 72: np.float32(-0.063554466), 73: np.float32(-0.090982616), 74: np.float32(-1.8301712), 75: np.float32(1.1938688), 76: np.float32(-0.4680833), 77: np.float32(-1.2901919), 78: np.float32(0.8510442), 79: np.float32(-2.4100955), 80: np.float32(0.8879638), 81: np.float32(-2.3858273), 82: np.float32(0.33003944), 83: np.float32(-1.1330237), 84: np.float32(0.35186934), 85: np.float32(0.64833885), 86: np.float32(-0.11127429), 87: np.float32(1.4799738), 88: np.float32(0.50751615), 89: np.float32(-0.22953692), 90: np.float32(-0.1868627), 91: np.float32(-0.80839455), 92: np.float32(0.2517218), 93: np.float32(1.0727955), 94: np.float32(0.54309833), 95: np.float32(0.7914056), 96: np.float32(-2.6392999), 97: np.float32(1.0665903), 98: np.float32(-0.082199305), 99: np.float32(-1.6929579), 100: np.float32(-0.7508289), 101: np.float32(-2.2105913), 102: np.float32(1.8662413), 103: np.float32(1.2833774), 104: np.float32(-0.39991984), 105: np.float32(-2.992206), 106: np.float32(0.94164413), 107: np.float32(-2.2196429), 108: np.float32(0.36182272), 109: np.float32(-0.38808143), 110: np.float32(-0.7853958), 111: np.float32(-2.6071591), 112: np.float32(0.31515738), 113: np.float32(0.5807231), 114: np.float32(0.6385585), 115: np.float32(-0.92789334), 116: np.float32(-0.4544401), 117: np.float32(-2.5203426), 118: np.float32(2.3191977), 119: np.float32(-0.03147936), 120: np.float32(-0.44769296), 121: np.float32(-2.468692), 122: np.float32(-0.83636963), 123: np.float32(-0.60596585), 124: np.float32(0.56364256), 125: np.float32(-0.47763902), 126: np.float32(1.8803058), 127: np.float32(-7.390976e-06), 128: np.float32(-2.824315), 129: np.float32(1.548954), 130: np.float32(0.20437694), 131: np.float32(-0.49661344), 132: np.float32(0.39963388), 133: np.float32(0.8811059), 134: np.float32(1.7594221), 135: np.float32(1.38697), 136: np.float32(0.6220596), 137: np.float32(-0.83346874), 138: np.float32(0.78054506), 139: np.float32(-0.5676464), 140: np.float32(0.7403831), 141: np.float32(-0.44433826), 142: np.floa ...

# %%
# Create two dictionaries for the t-SNE and UMAP embeddings for each dataset
linear_TSNE_dict = {
    "Convabuse combined": convabuse_combined_X_test_tsne,
    "Convabuse prev_agent": convabuse_prev_agent_X_test_tsne,
    "Convabuse prev_user": convabuse_prev_user_X_test_tsne,
    "Convabuse agent": convabuse_agent_X_test_tsne,
    "Convabuse user": convabuse_user_X_test_tsne,
    "Dynamically Generated Hate Speech target": dynamically_generated_hate_speech_target_target_X_test_tsne,
    "Dynamically Generated Hate Speech label": dynamically_generated_hate_speech_label_X_test_tsne,
    "MLMA Hate Speech target": mlma_hate_speech_target_X_test_tsne
}

linear_UMAP_dict = {
    "Convabuse combined": convabuse_combined_X_test_umap,
    "Convabuse prev_agent": convabuse_prev_agent_X_test_umap,
    "Convabuse prev_user": convabuse_prev_user_X_test_umap,
    "Convabuse agent": convabuse_agent_X_test_umap,
    "Convabuse user": convabuse_user_X_test_umap,
    "Dynamically Generated Hate Speech target": dynamically_generated_hate_speech_target_X_test_umap,
    "Dynamically Generated Hate Speech label": dynamically_generated_hate_speech_label_X_test_umap,
    "MLMA Hate Speech target": mlma_hate_speech_target_X_test_umap
}

# Pickle both dictionaries
with open(f'{pickle_path}linear-TSNE-dict_sentiment-analysis-SMOTE.pkl', 'wb') as f:
    pickle.dump(linear_TSNE_dict, f)
with open(f'{pickle_path}linear-UMAP-dict_sentiment-analysis-SMOTE.pkl', 'wb') as f:
    pickle.dump(linear_UMAP_dict, f)

# %%
# Create a dictionary where each dataset maps to its RMSE and R2
linear_model_summary_data = [
    {
        "Model": "Linear Regression",
        "Dataset": "Convabuse combined",
        "RMSE": convabuse_combined_linear_rmse,
        "R2": convabuse_combined_linear_r2,
        "Coefficients": convabuse_combined_linear_coefficients,
        "Feature Coefficients": convabuse_combined_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "Convabuse prev_agent",
        "RMSE": convabuse_prev_agent_linear_rmse,
        "R2": convabuse_prev_agent_linear_r2,
        "Coefficients": convabuse_prev_agent_linear_coefficients,
        "Feature Coefficients": convabuse_prev_agent_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "Convabuse prev_user",
        "RMSE": convabuse_prev_user_linear_rmse,
        "R2": convabuse_prev_user_linear_r2,
        "Coefficients": convabuse_prev_user_linear_coefficients,
        "Feature Coefficients": convabuse_prev_user_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "Convabuse agent",
        "RMSE": convabuse_agent_linear_rmse,
        "R2": convabuse_agent_linear_r2,
        "Coefficients": convabuse_agent_linear_coefficients,
        "Feature Coefficients": convabuse_agent_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "Convabuse user",
        "RMSE": convabuse_user_linear_rmse,
        "R2": convabuse_user_linear_r2,
        "Coefficients": convabuse_user_linear_coefficients,
        "Feature Coefficients": convabuse_user_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "Dynamically Generated Hate Speech target",
        "RMSE": dynamically_generated_hate_speech_target_linear_rmse,
        "R2": dynamically_generated_hate_speech_target_linear_r2,
        "Coefficients": dynamically_generated_hate_speech_target_linear_coefficients,
        "Feature Coefficients": dynamically_generated_hate_speech_target_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "Dynamically Generated Hate Speech label",
        "RMSE": dynamically_generated_hate_speech_label_linear_rmse,
        "R2": dynamically_generated_hate_speech_label_linear_r2,
        "Coefficients": dynamically_generated_hate_speech_label_linear_coefficients,
        "Feature Coefficients": dynamically_generated_hate_speech_label_top_10_coefficients
    },
    {
        "Model": "Linear Regression",
        "Dataset": "MLMA Hate Speech target",
        "RMSE": mlma_hate_speech_target_linear_rmse,
        "R2": mlma_hate_speech_target_linear_r2,
        "Coefficients": mlma_hate_speech_target_linear_coefficients,
        "Feature Coefficients": mlma_hate_speech_target_top_10_coefficients
    }
]

# Convert to DataFrame (datasets become rows, metrics are columns)
linear_model_summary = pd.DataFrame(linear_model_summary_data)
linear_model_summary["Balance"] = "SMOTE"
linear_model_summary
# Out:
#                Model                                   Dataset      RMSE  \
# 0  Linear Regression                        Convabuse combined  1.095880
# 1  Linear Regression                      Convabuse prev_agent  1.600719
# 2  Linear Regression                       Convabuse prev_user  1.555981
# 3  Linear Regression                           Convabuse agent  1.605151
# 4  Linear Regression                            Convabuse user  0.906083
# 5  Linear Regression  Dynamically Generated Hate Speech target  0.454677
# 6  Linear Regression   Dynamically Generated Hate Speech label  0.439308
# 7  Linear Regression                   MLMA Hate Speech target  0.807339
#
#          R2                                       Coefficients  \
# 0 -0.190663  {0: 0.78184676, 1: -1.7248409, 2: 0.9638579, 3...
# 1 -1.540347  {0: 5.253629, 1: 5.85519, 2: 2.273502, 3: 0.43...
# 2 -1.400332  {0: -0.6975128, 1: -1.5159559, 2: -1.9255601, ...
# 3 -1.554435  {0: -0.72618026, 1: 0.72120565, 2: 3.206022, 3...
# 4  0.186048  {0: -1.0281126, 1: 0.47622895, 2: 2.2835937, 3...
# 5 -0.120663  {0: -0.23720637, 1: -0.43264133, 2: -0.4024073...
# 6  0.223866  {0: -0.20349869, 1: 0.2109878, 2: -0.3860342, ...
# 7 -0.837957  {0: -1.0401444, 1: -0.7909471, 2: -1.0219293, ...
#
#                                 Feature Coefficients Balance
# 0  {165: 5.5850844, 382: 5.0371785, 352: 4.993483...   SMOTE
# 1  {379: 12.949793, 273: 9.508967, 268: 9.120752,...   SMOTE
# 2  {130: 5.2098746, 169: 3.926147, 219: 3.825575,...   SMOTE
# 3  {185: 9.14351, 3: 8.625567, 279: 7.850523, 52:...   SMOTE
# 4  {157: 5.50272, 117: 3.2238429, 249: 3.1601136,...   SMOTE
# 5  {268: 0.8433245, 224: 0.8181921, 157: 0.739124...   SMOTE
# 6  {206: 0.9347662, 99: 0.7496796, 157: 0.7167652...   SMOTE
# 7  {283: 3.896449, 186: 3.1817932, 299: 2.913108,...   SMOTE

# %%
linear_model_summary.to_csv("/content/drive/My Drive/Online MSDS/MOD C2/Political Polarization/results/sentiment_analysis_model1_linear-model-summary_SMOTE.csv", index=False)
