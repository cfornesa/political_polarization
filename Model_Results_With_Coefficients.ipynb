# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
results_path = '/content/drive/My Drive/Online MSDS/MOD C2/Political Polarization/results/'
# results_path = 'results/'

# %%
linear_regression_imbalanced = pd.read_csv(f"{results_path}model1_linear-model-summary_imbalanced.csv")
linear_regression_resampled = pd.read_csv(f"{results_path}model1_linear-model-summary_resampled.csv")
linear_regression_SMOTE = pd.read_csv(f"{results_path}model1_linear-model-summary_SMOTE.csv")

logistic_regression_imbalanced = pd.read_csv(f"{results_path}model4_logistic-regression-summary_imbalanced.csv")
logistic_regression_resampled = pd.read_csv(f"{results_path}model4_logistic-regression-summary_resampled.csv")
logistic_regression_SMOTE = pd.read_csv(f"{results_path}model4_logistic-regression-summary_SMOTE.csv")
logistic_regression_weighted = pd.read_csv(f"{results_path}model4_logistic-regression-summary_weighted.csv")

svm_classification_imbalanced = pd.read_csv(f"{results_path}model5_svm-classification-summary_imbalanced.csv")
svm_classification_resampled = pd.read_csv(f"{results_path}model5_svm-classification-summary_resampled.csv")
svm_classification_SMOTE = pd.read_csv(f"{results_path}model5_svm-classification-summary_SMOTE.csv")
svm_classification_weighted = pd.read_csv(f"{results_path}model5_svm-classification-summary_weighted.csv")
svm_regression_resampled = pd.read_csv(f"{results_path}model5_svm-regression-summary_resampled.csv")

dt_classification_imbalanced = pd.read_csv(f"{results_path}model6_dt-classification-summary_imbalanced.csv")
dt_classification_resampled = pd.read_csv(f"{results_path}model6_dt-classification-summary_resampled.csv")
dt_classification_SMOTE = pd.read_csv(f"{results_path}model6_dt-classification-summary_SMOTE.csv")
dt_classification_weighted = pd.read_csv(f"{results_path}model6_dt-classification-summary_weighted.csv")
dt_regression_resampled = pd.read_csv(f"{results_path}model6_dt-regression-summary_resampled.csv")

rf_classification_imbalanced = pd.read_csv(f"{results_path}model6_rf-classification-summary_imbalanced.csv")
rf_classification_resampled = pd.read_csv(f"{results_path}model6_rf-classification-summary_resampled.csv")
rf_classification_SMOTE = pd.read_csv(f"{results_path}model6_rf-classification-summary_SMOTE.csv")
rf_classification_weighted = pd.read_csv(f"{results_path}model6_rf-classification-summary_weighted.csv")
rf_regression_resampled = pd.read_csv(f"{results_path}model6_rf-regression-summary_resampled.csv")

knn_classification_imbalanced = pd.read_csv(f"{results_path}model8_knn-classification-summary_imbalanced.csv")
knn_classification_resampled = pd.read_csv(f"{results_path}model8_knn-classification-summary_resampled.csv")
knn_classification_SMOTE = pd.read_csv(f"{results_path}model8_knn-classification-summary_SMOTE.csv")
knn_regression_resampled = pd.read_csv(f"{results_path}model8_knn-regression-summary_resampled.csv")

gb_classification_imbalanced = pd.read_csv(f"{results_path}model9_gb-classification-summary-imbalanced.csv")
gb_classification_resampled = pd.read_csv(f"{results_path}model9_gb-classification-summary-resampled.csv")
gb_regression_resampled = pd.read_csv(f"{results_path}model9_gb-regression-summary-resampled.csv")

xgb_classification_imbalanced = pd.read_csv(f"{results_path}model9_gb-classification-summary-xgb-imbalanced.csv")
xgb_classification_resampled = pd.read_csv(f"{results_path}model9_gb-classification-summary-xgb-resampled.csv")
xgb_classification_weighted = pd.read_csv(f"{results_path}model9_gb-classification-summary-xgb-weighted.csv")
xgb_regression_resampled = pd.read_csv(f"{results_path}model9_gb-regression-summary-xgb-resampled.csv")

kmeans_clustering_imbalanced = pd.read_csv(f"{results_path}model10_kmeans-clustering-summary_imbalanced.csv")
kmeans_clustering_resampled = pd.read_csv(f"{results_path}model10_kmeans-clustering-summary_resampled.csv")
kmeans_clustering_SMOTE = pd.read_csv(f"{results_path}model10_kmeans-clustering-summary_SMOTE.csv")

# %%
linear_regression_imbalanced.head()
# Out:
#                Model                            Dataset      RMSE        R2  \
# 0  Linear Regression                          Convabuse  0.330115  0.891958
# 1  Linear Regression  Dynamically Generated Hate Speech  0.338133  0.540195
# 2  Linear Regression      US Elections 2020 Hate Speech  0.310790  0.064087
# 3  Linear Regression                   MLMA Hate Speech  0.671301  0.076915
#
#                                         Coefficients  \
# 0  {'annotator_id': np.float64(0.0211623065364701...
# 1  {'type': np.float64(-0.3710247267464888), 'ann...
# 2  {'Trump': np.float64(-0.05392014424852679), 'B...
# 3  {'shock_annotator_sentiment': np.float64(0.014...
#
#                                 Feature Coefficients     Balance
# 0  {'system': np.float64(0.48385017824834126), 'e...  Imbalanced
# 1  {'original': np.float64(0.10876639976590403), ...  Imbalanced
# 2  {'West': np.float64(0.0), 'Trump': np.float64(...  Imbalanced
# ...

# %%
linear_regression_resampled.head()
# Out:
#                Model                            Dataset          RMSE  \
# 0  Linear Regression                          Convabuse  6.394386e-01
# 1  Linear Regression  Dynamically Generated Hate Speech  3.349200e-01
# 2  Linear Regression             Online Abusive Attacks  3.541690e-13
# 3  Linear Regression      US Elections 2020 Hate Speech  4.710882e-01
# 4  Linear Regression                   MLMA Hate Speech  1.023212e+00
#
#          R2                                       Coefficients  \
# 0  0.795539  {'annotator_id': np.float64(0.0891325421479631...
# 1  0.551314  {'type': np.float64(-0.37591947687307), 'annot...
# 2  1.000000  {'Parent tweets': np.float64(0.275934286530178...
# 3  0.112304  {'Trump': np.float64(-0.12802209933773415), 'B...
# 4  0.162586  {'shock_annotator_sentiment': np.float64(0.013...
#
#                                 Feature Coefficients    Balance
# 0  {'system': np.float64(0.6812356291906492), 'ex...  Resampled
# ...

# %%
linear_regression_SMOTE.head()
# Out:
#                Model                            Dataset      RMSE        R2  \
# 0  Linear Regression                          Convabuse  0.645283  0.791794
# 1  Linear Regression  Dynamically Generated Hate Speech  0.333085  0.556217
# 2  Linear Regression      US Elections 2020 Hate Speech  0.466779  0.128471
# 3  Linear Regression                   MLMA Hate Speech  1.026703  0.156705
#
#                                         Coefficients  \
# 0  {'annotator_id': np.float64(0.0924749766950985...
# 1  {'type': np.float64(-0.38253202005709663), 'an...
# 2  {'Trump': np.float64(-0.17322390985672034), 'B...
# 3  {'shock_annotator_sentiment': np.float64(0.017...
#
#                                 Feature Coefficients Balance
# 0  {'explicit': np.float64(0.45529909401421254), ...   SMOTE
# 1  {'original': np.float64(0.10397921440364759), ...   SMOTE
# 2  {'West': np.float64(0.0), 'Trump': np.float64(...   SMOTE
# 3  {'sadness_annotator_sentiment': np.float64(0.1...   SMOTE

# %%
logistic_regression_imbalanced.head()
# Out:
#                   Dataset Regularizer     Solver  Accuracy  F1-score  Ratio  \
# 0               Convabuse          l1  liblinear  0.885533  0.852027    0.0
# 1                    DGHS          l1  liblinear  0.827553  0.808568    0.0
# 2  Online Abusive Attacks          l1       saga  0.812095  0.800787    0.0
# 3                US2020HS          l1  liblinear  0.883139  0.000000    0.0
# 4        MLMA Hate Speech          l1       saga  0.596364  0.496579    0.0
#
#                                  Feature Importances     Balance  \
# 0  {'bot': 0.5777202483608284, 'generalised': 0.0...  Imbalanced
# 1  {'original': 3.880785596630201, 'target_groups...  Imbalanced
# 2  {'Toxic replies': -6.170820812897218, 'Toxic p...  Imbalanced
# 3  {'West': 0.0, 'Trump': -0.5047453980305149, 'B...  Imbalanced
# 4  {'Not Abusive': 0.3372934904240555, 'indiffere...  Imbalanced
#
#                  Model
# 0  Logistic Regression
# 1  Logistic Regression
# 2  Logistic Regression
# ...

# %%
logistic_regression_resampled.head()
# Out:
#                   Dataset Regularizer     Solver  Accuracy  F1-score  Ratio  \
# 0               Convabuse          l1       saga  0.548797  0.534900    0.0
# 1                    DGHS          l1  liblinear  0.836848  0.805039    0.0
# 2  Online Abusive Attacks          l1       saga  0.903777  0.897601    0.0
# 3                US2020HS          l1  liblinear  0.643939  0.643939    0.0
# 4        MLMA Hate Speech          l2  liblinear  0.238278  0.092972    0.0
#
#                                  Feature Importances Balance  \
# 0  {'bot': 0.3135946990754108, 'generalised': 0.0...   SMOTE
# 1  {'original': 3.8367515347660825, 'target_group...   SMOTE
# 2  {'index': -0.24873302012164952, 'Toxic replies...   SMOTE
# 3  {'West': 0.0, 'Trump': -0.5361364908316495, 'B...   SMOTE
# 4  {'implicit': 0.0001300202623139896, 'abuse_lev...   SMOTE
#
#                  Model
# 0  Logistic Regression
# 1  Logistic Regression
# 2  Logistic Regression
# 3  Logistic Regression
# ...

# %%
logistic_regression_SMOTE.head()
# Out:
#                   Dataset Regularizer     Solver  Accuracy  F1-score  Ratio  \
# 0               Convabuse          l1       saga  0.544967  0.513890    0.0
# 1                    DGHS          l1  liblinear  0.838416  0.807275    0.0
# 2  Online Abusive Attacks          l1       saga  0.903777  0.898398    0.0
# 3                US2020HS          l1  liblinear  0.648674  0.650330    0.0
# 4        MLMA Hate Speech          l2  liblinear  0.575000  0.419841    0.0
#
#                                  Feature Importances Balance  \
# 0  {'bot': 0.5859231731296082, 'generalised': 0.0...   SMOTE
# 1  {'original': 3.871260109046368, 'target_groups...   SMOTE
# 2  {'Toxic replies': -7.789314268739111, 'Toxic p...   SMOTE
# 3  {'West': 0.0, 'Biden': -0.5157701187647922, 'T...   SMOTE
# 4  {'implicit': 0.3859362706501835, 'abuse_level'...   SMOTE
#
#                  Model
# 0  Logistic Regression
# 1  Logistic Regression
# 2  Logistic Regression
# 3  Logistic Regression
# ...

# %%
logistic_regression_weighted.head()
# Out:
#                   Dataset Regularizer     Solver  Accuracy  F1-score  Ratio  \
# 0               Convabuse          l1  liblinear  0.885533  0.853066    0.0
# 1                    DGHS          l1  liblinear  0.827553  0.808568    0.0
# 2  Online Abusive Attacks          l1  liblinear  0.868251  0.864666    0.0
# 3                US2020HS          l1  liblinear  0.646077  0.307190    0.0
# 4        MLMA Hate Speech          l1  liblinear  0.467857  0.459772    0.0
#
#                                  Feature Importances   Balance  \
# 0  {'bot': 0.5775275892056827, 'generalised': 0.0...  Weighted
# 1  {'original': 3.851019278039954, 'target_groups...  Weighted
# 2  {'Toxic replies': -16.193728095652887, 'Toxic ...  Weighted
# 3  {'West': 0.0, 'Biden': -0.5153487915313094, 'T...  Weighted
# 4  {'implicit': 0.0, 'abuse_level': -0.0760710347...  Weighted
#
#                  Model
# 0  Logistic Regression
# 1  Logistic Regression
# 2  Logistic Regression
# 3  Logistic Regression
# ...

# %%
svm_classification_imbalanced.head()
# Out:
#                              Dataset  Kernel Regularization  Accuracy  \
# 0                          Convabuse  Linear             L1  0.885533
# 1                          Convabuse     RBF             L2  0.873609
# 2                          Convabuse  linear             L1  0.094197
# 3  Dynamically Generated Hate Speech  Linear             L1  0.827553
# 4  Dynamically Generated Hate Speech     RBF             L2  0.645701
#
#    F1 Score                            Permutation Importances     Balance  \
# 0  0.852027  {'implicit': 0.035771065182829874, 'explicit':...  Imbalanced
# 1  0.841417  {'explicit': 0.10119236883942766, 'system': 0....  Imbalanced
# 2  0.042533                                                NaN  Imbalanced
# 3  0.824574  {'type': 0.3356863702979971, 'annotator': 0.0,...  Imbalanced
# 4  0.618876  {'target_groups': 0.08031265266243284, 'type':...  Imbalanced
#
#                     Model
# 0  Support Vector Machine
# 1  Support Vector Machine
# ...

# %%
svm_classification_resampled.head()
# Out:
#                              Dataset  Kernel Regularization  Accuracy  \
# 0                          Convabuse  Linear             L1  0.535679
# 1                          Convabuse     RBF             L2  0.535878
# 2                          Convabuse  linear             L1  0.425959
# 3  Dynamically Generated Hate Speech  Linear             L1  0.836848
# 4  Dynamically Generated Hate Speech     RBF             L2  0.738535
#
#    F1 Score                            Permutation Importances Balance  \
# 0  0.513819  {'system': 0.11788908765652953, 'implicit': 0....   SMOTE
# 1  0.519120  {'system': 0.22393162393162394, 'explicit': 0....   SMOTE
# 2  0.367661  {'system': 0.1969787318624528, 'implicit': 0.0...   SMOTE
# 3  0.832386  {'type': 0.33510806536636795, 'annotator': 0.0...   SMOTE
# 4  0.736685  {'type': 0.18302583025830263, 'target_groups':...   SMOTE
#
#                     Model
# 0  Support Vector Machine
# 1  Support Vector Machine
# 2  Support Vector Machine
# ...

# %%
svm_classification_SMOTE.head()
# Out:
#                              Dataset  Kernel Regularization  Accuracy  \
# 0                          Convabuse  Linear             L1  0.546954
# 1                          Convabuse     RBF             L2  0.518533
# 2                          Convabuse  linear             L1  0.427010
# 3  Dynamically Generated Hate Speech  Linear             L1  0.838416
# 4  Dynamically Generated Hate Speech     RBF             L2  0.820323
#
#    F1 Score                            Permutation Importances Balance  \
# 0  0.516532  {'explicit': 0.11790718473616224, 'implicit': ...   SMOTE
# 1  0.454423  {'explicit': 0.1814270098380205, 'implicit': 0...   SMOTE
# 2  0.291854  {'explicit': 0.09825101858292758, 'system': 0....   SMOTE
# 3  0.834084  {'type': 0.33962221210741916, 'annotator': 0.0...   SMOTE
# 4  0.814329  {'type': 0.24119253527537549, 'target_groups':...   SMOTE
#
#                     Model
# 0  Support Vector Machine
# 1  Support Vector Machine
# 2  Support Vector Machine
# ...

# %%
svm_classification_weighted.head()
# Out:
#                              Dataset  Kernel Regularization  Accuracy  \
# 0                          Convabuse  Linear             L1  0.885533
# 1                          Convabuse     RBF             L2  0.869237
# 2                          Convabuse  linear             L1  0.094197
# 3  Dynamically Generated Hate Speech  Linear             L1  0.827553
# 4  Dynamically Generated Hate Speech     RBF             L2  0.827553
#
#    F1 Score                            Permutation Importances   Balance  \
# 0  0.853066  {'system': 0.08636724960254369, 'explicit': 0....  Weighted
# 1  0.841503  {'system': 0.1523052464228935, 'target_groups'...  Weighted
# 2  0.042533                                                NaN  Weighted
# 3  0.824574  {'type': 0.3356863702979971, 'annotator': 0.0,...  Weighted
# 4  0.824574  {'type': 0.17979970688812896, 'target_groups':...  Weighted
#
#                     Model
# 0  Support Vector Machine
# 1  Support Vector Machine
# ...

# %%
# Rename F1 Score to F1-score
svm_classification_imbalanced = svm_classification_imbalanced.rename(columns={'F1 Score': 'F1-score'})
svm_classification_resampled = svm_classification_resampled.rename(columns={'F1 Score': 'F1-score'})
svm_classification_SMOTE = svm_classification_SMOTE.rename(columns={'F1 Score': 'F1-score'})
svm_classification_weighted = svm_classification_weighted.rename(columns={'F1 Score': 'F1-score'})

# %%
svm_regression_resampled.head()
# Out:
#                   Dataset  Kernel Regularization      RMSE        R2  \
# 0  Online Abusive Attacks  Linear             L1  0.206173  0.999989
# 1  Online Abusive Attacks  linear             L1  4.030116  0.995804
#
#                              Permutation Importances    Balance  \
# 0  {'High profanity parents': 0.30193062202308624...  Resampled
# 1  {'High profanity parents': 0.29917756885580116...  Resampled
#
#                     Model
# 0  Support Vector Machine
# 1  Support Vector Machine

# %%
# Rename Permutation Importances to Feature Coefficients
svm_regression_resampled = svm_regression_resampled.rename(columns={'Permutation Importances': 'Feature Coefficients'})

# %%
dt_classification_imbalanced = pd.read_csv(f"{results_path}model6_dt-classification-summary_imbalanced.csv")
dt_classification_resampled = pd.read_csv(f"{results_path}model6_dt-classification-summary_resampled.csv")
dt_classification_SMOTE = pd.read_csv(f"{results_path}model6_dt-classification-summary_SMOTE.csv")
dt_classification_weighted = pd.read_csv(f"{results_path}model6_dt-classification-summary_weighted.csv")

# %%
dt_classification_imbalanced.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Decision Tree                          Convabuse     NaN             NaN
# 1  Decision Tree  Dynamically Generated Hate Speech     NaN             NaN
# 2  Decision Tree             Online Abusive Attacks     NaN             NaN
# 3  Decision Tree      US Elections 2020 Hate Speech     NaN             NaN
# 4  Decision Tree                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.876391  0.842223    0.0
# 1  0.842330  0.841923    0.0
# 2  0.974082  0.973596    0.0
# 3  0.883139  0.828334    0.0
# 4  0.599678  0.493751    0.0
#
#                                      Best Parameters  \
# 0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 1  {'dt_classifier__min_samples_split': 984, 'dt_...
# 2  {'dt_classifier__min_samples_split': 38, 'dt_c...
# 3  {'dt_classifier__min_samples_split': 72, 'dt_c...
# 4  {'dt_classifier__min_samples_split': 450, 'dt_...
#
# ...

# %%
dt_classification_resampled.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Decision Tree                          Convabuse     NaN             NaN
# 1  Decision Tree  Dynamically Generated Hate Speech     NaN             NaN
# 2  Decision Tree             Online Abusive Attacks     NaN             NaN
# 3  Decision Tree      US Elections 2020 Hate Speech     NaN             NaN
# 4  Decision Tree                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.614788  0.615371    0.0
# 1  0.847522  0.846292    0.0
# 2  0.935252  0.935062    0.0
# 3  0.688447  0.687829    0.0
# 4  0.450646  0.432456    0.0
#
#                                      Best Parameters  \
# 0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 1  {'dt_classifier__min_samples_split': 912, 'dt_...
# 2  {'dt_classifier__min_samples_split': 180, 'dt_...
# 3  {'dt_classifier__min_samples_split': 129, 'dt_...
# 4  {'dt_classifier__min_samples_split': 348, 'dt_...
#
# ...

# %%
dt_classification_SMOTE.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Decision Tree                          Convabuse     NaN             NaN
# 1  Decision Tree  Dynamically Generated Hate Speech     NaN             NaN
# 2  Decision Tree             Online Abusive Attacks     NaN             NaN
# 3  Decision Tree      US Elections 2020 Hate Speech     NaN             NaN
# 4  Decision Tree                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.534036  0.522117    0.0
# 1  0.845812  0.844547    0.0
# 2  0.955036  0.955082    0.0
# 3  0.704545  0.703456    0.0
# 4  0.447994  0.427240    0.0
#
#                                      Best Parameters  \
# 0  {'dt_classifier__min_samples_split': 1209, 'dt...
# 1  {'dt_classifier__min_samples_split': 1408, 'dt...
# 2  {'dt_classifier__min_samples_split': 180, 'dt_...
# 3  {'dt_classifier__min_samples_split': 129, 'dt_...
# 4  {'dt_classifier__min_samples_split': 1041, 'dt...
#
# ...

# %%
dt_classification_weighted.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Decision Tree                          Convabuse     NaN             NaN
# 1  Decision Tree  Dynamically Generated Hate Speech     NaN             NaN
# 2  Decision Tree             Online Abusive Attacks     NaN             NaN
# 3  Decision Tree      US Elections 2020 Hate Speech     NaN             NaN
# 4  Decision Tree                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.559618  0.636134    0.0
# 1  0.842330  0.841923    0.0
# 2  0.961123  0.962842    0.0
# 3  0.664441  0.724400    0.0
# 4  0.450161  0.389569    0.0
#
#                                      Best Parameters  \
# 0  {'dt_classifier__min_samples_split': 303, 'dt_...
# 1  {'dt_classifier__min_samples_split': 984, 'dt_...
# 2  {'dt_classifier__min_samples_split': 38, 'dt_c...
# 3  {'dt_classifier__min_samples_split': 72, 'dt_c...
# 4  {'dt_classifier__min_samples_split': 750, 'dt_...
#
# ...

# %%
dt_regression_resampled.head()
# Out:
#            Model                 Dataset       RMSE        R2  \
# 0  Decision Tree  Online Abusive Attacks  19.017708  0.906574
#
#                                      Best Parameters  \
# 0  {'dt_regressor__min_samples_split': 38, 'dt_re...
#
#                                         Coefficients  \
# 0  {'Toxic parent tweets': np.float64(0.726131924...
#
#                                 Feature Coefficients    Balance
# 0  {'Toxic parent tweets': np.float64(0.726131924...  Resampled

# %%
rf_classification_imbalanced.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Random Forest                          Convabuse     NaN             NaN
# 1  Random Forest  Dynamically Generated Hate Speech     NaN             NaN
# 2  Random Forest             Online Abusive Attacks     NaN             NaN
# 3  Random Forest      US Elections 2020 Hate Speech     NaN             NaN
# 4  Random Forest                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.883545  0.849268    0.0
# 1  0.840498  0.840163    0.0
# 2  0.969762  0.968153    0.0
# 3  0.876461  0.818758    0.0
# 4  0.601554  0.511696    0.0
#
#                                      Best Parameters  \
# 0  {'rf_classifier__n_estimators': 958, 'rf_class...
# 1  {'rf_classifier__n_estimators': 958, 'rf_class...
# 2  {'rf_classifier__n_estimators': 958, 'rf_class...
# 3  {'rf_classifier__n_estimators': 795, 'rf_class...
# 4  {'rf_classifier__n_estimators': 685, 'rf_class...
#
# ...

# %%
rf_classification_resampled.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Random Forest                          Convabuse     NaN             NaN
# 1  Random Forest  Dynamically Generated Hate Speech     NaN             NaN
# 2  Random Forest             Online Abusive Attacks     NaN             NaN
# 3  Random Forest      US Elections 2020 Hate Speech     NaN             NaN
# 4  Random Forest                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.619559  0.620160    0.0
# 1  0.852399  0.851308    0.0
# 2  0.957734  0.957913    0.0
# 3  0.703598  0.702632    0.0
# 4  0.441421  0.429746    0.0
#
#                                      Best Parameters  \
# 0  {'rf_classifier__n_estimators': 958, 'rf_class...
# 1  {'rf_classifier__n_estimators': 958, 'rf_class...
# 2  {'rf_classifier__n_estimators': 958, 'rf_class...
# 3  {'rf_classifier__n_estimators': 795, 'rf_class...
# 4  {'rf_classifier__n_estimators': 962, 'rf_class...
#
# ...

# %%
rf_classification_SMOTE.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Random Forest                          Convabuse     NaN             NaN
# 1  Random Forest  Dynamically Generated Hate Speech     NaN             NaN
# 2  Random Forest             Online Abusive Attacks     NaN             NaN
# 3  Random Forest      US Elections 2020 Hate Speech     NaN             NaN
# 4  Random Forest                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.883545  0.849268    0.0
# 1  0.840498  0.840163    0.0
# 2  0.969762  0.968153    0.0
# 3  0.876461  0.818758    0.0
# 4  0.601554  0.511696    0.0
#
#                                      Best Parameters  \
# 0  {'rf_classifier__n_estimators': 958, 'rf_class...
# 1  {'rf_classifier__n_estimators': 958, 'rf_class...
# 2  {'rf_classifier__n_estimators': 958, 'rf_class...
# 3  {'rf_classifier__n_estimators': 795, 'rf_class...
# 4  {'rf_classifier__n_estimators': 685, 'rf_class...
#
# ...

# %%
rf_classification_weighted.head()
# Out:
#            Model                            Dataset  Kernel  Regularization  \
# 0  Random Forest                          Convabuse     NaN             NaN
# 1  Random Forest  Dynamically Generated Hate Speech     NaN             NaN
# 2  Random Forest             Online Abusive Attacks     NaN             NaN
# 3  Random Forest      US Elections 2020 Hate Speech     NaN             NaN
# 4  Random Forest                   MLMA Hate Speech     NaN             NaN
#
#    Accuracy  F1-score  Ratio  \
# 0  0.669714  0.737168    0.0
# 1  0.840498  0.840163    0.0
# 2  0.963283  0.964974    0.0
# 3  0.656093  0.714833    0.0
# 4  0.387996  0.411136    0.0
#
#                                      Best Parameters  \
# 0  {'rf_classifier__n_estimators': 886, 'rf_class...
# 1  {'rf_classifier__n_estimators': 958, 'rf_class...
# 2  {'rf_classifier__n_estimators': 958, 'rf_class...
# 3  {'rf_classifier__n_estimators': 795, 'rf_class...
# 4  {'rf_classifier__n_estimators': 860, 'rf_class...
#
# ...

# %%
knn_classification_imbalanced.head()
# Out:
#                  Model                            Dataset  Kernel  \
# 0  K-Nearest Neighbors                          Convabuse     NaN
# 1  K-Nearest Neighbors  Dynamically Generated Hate Speech     NaN
# 2  K-Nearest Neighbors             Online Abusive Attacks     NaN
# 3  K-Nearest Neighbors      US Elections 2020 Hate Speech     NaN
# 4  K-Nearest Neighbors                   MLMA Hate Speech     NaN
#
#    Regularization  Accuracy  F1-score  Ratio  \
# 0             NaN  0.885533  0.852027    0.0
# 1             NaN  0.842330  0.841923    0.0
# 2             NaN  0.993521  0.993524    0.0
# 3             NaN  0.883139  0.828334    0.0
# 4             NaN  0.599411  0.490359    0.0
#
#                                      Best Parameters  \
# 0  {'knn_classifier__metric': 'euclidean', 'knn_c...
# 1  {'knn_classifier__metric': 'euclidean', 'knn_c...
# 2  {'knn_classifier__metric': 'euclidean', 'knn_c...
# 3  {'knn_classifier__metric': 'euclidean', 'knn_c...
# ...

# %%
knn_classification_resampled.head()
# Out:
#                  Model                            Dataset  Kernel  \
# 0  K-Nearest Neighbors                          Convabuse     NaN
# 1  K-Nearest Neighbors  Dynamically Generated Hate Speech     NaN
# 2  K-Nearest Neighbors      US Elections 2020 Hate Speech     NaN
# 3  K-Nearest Neighbors                   MLMA Hate Speech     NaN
#
#    Regularization  Accuracy  F1-score  Ratio  \
# 0             NaN  0.619758  0.617044    0.0
# 1             NaN  0.833026  0.830199    0.0
# 2             NaN  0.625000  0.607660    0.0
# 3             NaN  0.529329  0.521837    0.0
#
#                                      Best Parameters  \
# 0  {'knn_classifier__metric': 'euclidean', 'knn_c...
# 1  {'knn_classifier__metric': 'euclidean', 'knn_c...
# 2  {'knn_classifier__metric': 'euclidean', 'knn_c...
# 3  {'knn_classifier__metric': 'euclidean', 'knn_c...
#
#                                          Importances  \
# 0  {'annotator_id': np.float64(0.1477241105148082...
# ...

# %%
knn_classification_SMOTE.head()
knn_classification_SMOTE["Balance"] = "SMOTE"

# %%
knn_regression_resampled.head()
# Out:
#                  Model                 Dataset       RMSE        R2  \
# 0  K-Nearest Neighbors  Online Abusive Attacks  12.522529  0.959493
#
#                                      Best Parameters  \
# 0  {'knn_regressor__metric': 'euclidean', 'knn_re...
#
#                                         Coefficients  \
# 0  {'Parent tweets': np.float64(0.004320409611475...
#
#                                 Feature Coefficients    Balance
# 0  {'High identity_attack parents': np.float64(0....  Resampled

# %%
gb_classification_imbalanced.head()
gb_classification_imbalanced["Balance"] = "Imbalanced"

# %%
gb_classification_resampled.head()
gb_classification_resampled["Balance"] = "Resampled"

# %%
gb_regression_resampled.head()
# Out:
# Empty DataFrame
# Columns: [Model, Dataset, RMSE, R2, Best Parameters, Feature Importances, Resampled]
# Index: []

# %%
# Rename Feature Importances to Feature Coefficients
gb_regression_resampled = gb_regression_resampled.rename(columns={'Feature Importances': 'Feature Coefficients'})

# %%
xgb_classification_imbalanced.head()
# Out:
#                Model                            Dataset  Kernel  \
# 0  Gradient Boosting                          Convabuse     NaN
# 1  Gradient Boosting  Dynamically Generated Hate Speech     NaN
# 2  Gradient Boosting             Online Abusive Attacks     NaN
# 3  Gradient Boosting      US Elections 2020 Hate Speech     NaN
# 4  Gradient Boosting                   MLMA Hate Speech     NaN
#
#    Regularization  Accuracy  F1-score  \
# 0             NaN  0.800079  0.711221
# 1             NaN  0.536639  0.374820
# 2             NaN  0.477322  0.308445
# 3             NaN  0.883139  0.828334
# 4             NaN  0.580922  0.426928
#
#                                                Ratio  \
# 0                                                0.0
# 1                                                0.0
# 2  {'xgb__learning_rate': np.float64(0.01), 'xgb_...
# 3                                                0.0
# 4                                                0.0
#
# ...

# %%
xgb_classification_resampled.head()
# Out:
#                Model                            Dataset  Kernel  \
# 0  Gradient Boosting                          Convabuse     NaN
# 1  Gradient Boosting  Dynamically Generated Hate Speech     NaN
# 2  Gradient Boosting             Online Abusive Attacks     NaN
# 3  Gradient Boosting      US Elections 2020 Hate Speech     NaN
# 4  Gradient Boosting                   MLMA Hate Speech     NaN
#
#    Regularization  Accuracy  F1-score  \
# 0             NaN  0.199960  0.066642
# 1             NaN  0.500000  0.333333
# 2             NaN  0.236511  0.140523
# 3             NaN  0.500000  0.333333
# 4             NaN  0.250000  0.100000
#
#                                                Ratio  \
# 0                                                0.0
# 1                                                0.0
# 2  {'xgb__learning_rate': np.float64(0.0200000000...
# 3                                                0.0
# 4                                                0.0
#
# ...

# %%
xgb_classification_weighted.head()
# Out:
#                Model                            Dataset  Kernel  \
# 0  Gradient Boosting                          Convabuse     NaN
# 1  Gradient Boosting  Dynamically Generated Hate Speech     NaN
# 2  Gradient Boosting             Online Abusive Attacks     NaN
# 3  Gradient Boosting      US Elections 2020 Hate Speech     NaN
# 4  Gradient Boosting                   MLMA Hate Speech     NaN
#
#    Regularization  Accuracy  F1-score  \
# 0             NaN  0.885533  0.852027
# 1             NaN  0.535051  0.518128
# 2             NaN  0.758099  0.729504
# 3             NaN  0.601002  0.668059
# 4             NaN  0.182744  0.120676
#
#                                                Ratio  \
# 0                                                0.0
# 1                                                0.0
# 2  {'xgb__learning_rate': np.float64(0.01), 'xgb_...
# 3                                                0.0
# 4                                                0.0
#
# ...

# %%
xgb_regression_resampled.head()
# Out:
#                Model                 Dataset       RMSE        R2  \
# 0  Gradient Boosting  Online Abusive Attacks  75.204177 -0.460949
#
#                                      Best Parameters  \
# 0  {'xgb__learning_rate': np.float64(0.1), 'xgb__...
#
#                                  Feature Importances  Resampled
# 0  {'Parent tweets with replies': np.float32(0.97...  Resampled

# %%
# Rename Feature Importances to Feature Coefficients
xgb_regression_resampled = xgb_regression_resampled.rename(columns={'Feature Importances': 'Feature Coefficients'})

# %%
kmeans_clustering_imbalanced.head()
# Out:
#                              Dataset  Best Model Silhouette Score  \
# 0                          Convabuse                     0.513327
# 1  Dynamically Generated Hate Speech                     0.603673
# 2             Online Abusive Attacks                     0.400000
# 3      US Elections 2020 Hate Speech                     0.666667
# 4                   MLMA Hate Speech                     0.659905
#
#    Best Model Inertia  Chosen Model Silhouette Score  Chosen Model Inertia  \
# 0           50.106688                       0.661070          3.098136e+01
# 1          869.751854                       0.657663          1.641114e+02
# 2           40.537527                            NaN          1.160907e+00
# 3            3.879310                       0.666667          1.048646e-28
# 4           50.600016                       0.651497          9.166949e+00
#
#                                      Best Parameters  \
# 0  {'init': 'k-means++', 'max_iter': 1, 'n_init':...
# ...

# %%
kmeans_clustering_resampled.head()
# Out:
#                              Dataset  Best Model Silhouette Score  \
# 0                          Convabuse                     0.589957
# 1  Dynamically Generated Hate Speech                     0.569834
# 2             Online Abusive Attacks                     0.142857
# 3      US Elections 2020 Hate Speech                     0.636364
# 4                   MLMA Hate Speech                     0.448927
#
#    Best Model Inertia  Chosen Model Silhouette Score  Chosen Model Inertia  \
# 0        1.812015e+02                       0.640346          3.373622e+01
# 1        8.285915e+02                       0.676209          1.233983e+02
# 2        1.827307e+01                       0.346683          1.366048e+01
# 3        2.619265e-30                       0.636364          9.856139e-29
# 4        1.528755e+02                       0.397709          1.352768e+02
#
#                                      Best Parameters  \
# 0  {'init': 'k-means++', 'max_iter': 1, 'n_init': 1}
# ...

# %%
kmeans_clustering_SMOTE.head()
# Out:
#                              Dataset  Best Model Silhouette Score  \
# 0                          Convabuse                     0.624671
# 1  Dynamically Generated Hate Speech                     0.605949
# 2      US Elections 2020 Hate Speech                     0.608510
# 3                   MLMA Hate Speech                     0.197870
#
#    Best Model Inertia  Chosen Model Silhouette Score  Chosen Model Inertia  \
# 0          231.569622                       0.680004            371.483143
# 1          973.071098                       0.672281            191.073745
# 2            2.744993                       0.556711              0.729075
# 3         1735.592767                       0.302355           1208.708738
#
#                                      Best Parameters  \
# 0  {'init': 'k-means++', 'max_iter': 1, 'n_init': 1}
# 1  {'init': 'k-means++', 'max_iter': 7, 'n_init': 2}
# 2  {'init': 'k-means++', 'max_iter': 1, 'n_init': 3}
# ...

# %%
sentiment_analysis_linear_regression_imbalanced = pd.read_csv(f"{results_path}sentiment_analysis_model1_linear-model-summary_imbalanced.csv")
sentiment_analysis_linear_regression_resampled = pd.read_csv(f"{results_path}sentiment_analysis_model1_linear-model-summary_resampled.csv")
sentiment_analysis_linear_regression_SMOTE = pd.read_csv(f"{results_path}sentiment_analysis_model1_linear-model-summary_SMOTE.csv")

sentiment_analysis_logistic_regression_imbalanced = pd.read_csv(f"{results_path}sentiment_analysis_model4_logistic-regression-summary_imbalanced.csv")
sentiment_analysis_logistic_regression_resampled = pd.read_csv(f"{results_path}sentiment_analysis_model4_logistic-regression-summary_resampled.csv")
sentiment_analysis_logistic_regression_SMOTE = pd.read_csv(f"{results_path}sentiment_analysis_model4_logistic-regression-summary_SMOTE.csv")
sentiment_analysis_logistic_regression_weighted = pd.read_csv(f"{results_path}sentiment_analysis_model4_logistic-regression-summary_weighted.csv")

sentiment_analysis_decision_tree_imbalanced = pd.read_csv(f"{results_path}sentiment_analysis_model6_dt-classification-summary_imbalanced.csv")
sentiment_analysis_decision_tree_resampled = pd.read_csv(f"{results_path}sentiment_analysis_model6_dt-classification-summary_resampled.csv")
sentiment_analysis_decision_tree_SMOTE = pd.read_csv(f"{results_path}sentiment_analysis_model6_dt-classification-summary_SMOTE.csv")
sentiment_analysis_decision_tree_weighted = pd.read_csv(f"{results_path}sentiment_analysis_model6_dt-classification-summary_weighted.csv")

neural_network_convabuse = pd.read_csv(f"{results_path}model12_neural-network-summary_convabuse_SMOTE.csv")
neural_network_mixed_convabuse = pd.read_csv(f"{results_path}model12_neural-network-summary_convabuse_mixed.csv")
neural_network_mixed_SMOTE_convabuse = pd.read_csv(f"{results_path}model12_neural-network-summary_convabuse_SMOTE_mixed.csv")
neural_network_mixed_mlma = pd.read_csv(f"{results_path}model12_neural-network-summary_mlma_mixed.csv")
neural_network_mixed_SMOTE_mlma = pd.read_csv(f"{results_path}model12_neural-network-summary_mlma_SMOTE_mixed.csv")
neural_network_dghs = pd.read_csv(f"{results_path}model12_neural-network-summary_dghs_SMOTE.csv")
neural_network_mlma = pd.read_csv(f"{results_path}model12_neural-network-summary_mlma_SMOTE.csv")
neural_network_us2020hs = pd.read_csv(f"{results_path}model12_neural-network-summary_us-elections_SMOTE.csv")
neural_network_oaa = pd.read_csv(f"{results_path}model12_neural-network-summary_oaa_SMOTE.csv")

sentiment_analysis_neural_network_imbalanced = pd.read_csv(f"{results_path}sentiment_analysis_model12_neural-network-summary_imbalanced.csv")
sentiment_analysis_neural_network_resampled = pd.read_csv(f"{results_path}sentiment_analysis_model12_neural-network-summary_resampled.csv")
sentiment_analysis_neural_network_SMOTE_Convabuse = pd.read_csv(f"{results_path}sentiment_analysis_model12_neural-network-summary_SMOTE-Convabuse.csv")
sentiment_analysis_neural_network_SMOTE_DGHS = pd.read_csv(f"{results_path}sentiment_analysis_model12_neural-network-summary_SMOTE-DGHS.csv")
sentiment_analysis_neural_network_SMOTE_MLMA = pd.read_csv(f"{results_path}sentiment_analysis_model12_neural-network-summary_SMOTE-MLMA.csv")
sentiment_analysis_neural_network_weighted = pd.read_csv(f"{results_path}sentiment_analysis_model12_neural-network-summary_weighted.csv")

# %%
sentiment_analysis_linear_regression_imbalanced.head()
# Out:
#                Model               Dataset      RMSE        R2  \
# 0  Linear Regression    Convabuse combined  0.754713  0.435288
# 1  Linear Regression  Convabuse prev_agent  0.979320  0.049150
# 2  Linear Regression   Convabuse prev_user  0.933107  0.136772
# 3  Linear Regression       Convabuse agent  0.956625  0.092710
# 4  Linear Regression        Convabuse user  0.639933  0.593995
#
#                                         Coefficients  \
# 0  {0: np.float32(1.0651855), 1: np.float32(-0.87...
# 1  {0: np.float32(3.074767), 1: np.float32(1.7563...
# 2  {0: np.float32(-0.0057446556), 1: np.float32(-...
# 3  {0: np.float32(-0.69703513), 1: np.float32(2.0...
# 4  {0: np.float32(-0.42043114), 1: np.float32(-0....
#
#                                 Feature Coefficients     Balance
# 0  {157: np.float32(3.9420588), 197: np.float32(2...  Imbalanced
# 1  {379: np.float32(9.122475), 133: np.float32(7....  Imbalanced
# 2  {255: np.float32(2.0723534), 130: np.float32(1...  Imbalanced
# ...

# %%
sentiment_analysis_linear_regression_resampled.head()
# Out:
#                Model               Dataset      RMSE        R2  \
# 0  Linear Regression    Convabuse combined  0.922944  0.574045
# 1  Linear Regression  Convabuse prev_agent  1.241402  0.229384
# 2  Linear Regression   Convabuse prev_user  1.171032  0.314274
# 3  Linear Regression       Convabuse agent  1.238993  0.232372
# 4  Linear Regression        Convabuse user  0.796734  0.682576
#
#                                         Coefficients  \
# 0  {0: np.float32(0.1374525), 1: np.float32(-1.03...
# 1  {0: np.float32(8.48053), 1: np.float32(6.26504...
# 2  {0: np.float32(-1.4956436), 1: np.float32(-1.8...
# 3  {0: np.float32(-4.9182234), 1: np.float32(3.42...
# 4  {0: np.float32(0.4993603), 1: np.float32(0.538...
#
#                                 Feature Coefficients    Balance
# 0  {117: np.float32(4.6621184), 165: np.float32(4...  Resampled
# 1  {355: np.float32(12.886696), 175: np.float32(1...  Resampled
# 2  {219: np.float32(4.1788597), 130: np.float32(4...  Resampled
# ...

# %%
sentiment_analysis_linear_regression_SMOTE.head()
# Out:
#                Model               Dataset      RMSE        R2  \
# 0  Linear Regression    Convabuse combined  1.095880 -0.190663
# 1  Linear Regression  Convabuse prev_agent  1.600719 -1.540347
# 2  Linear Regression   Convabuse prev_user  1.555981 -1.400332
# 3  Linear Regression       Convabuse agent  1.605151 -1.554435
# 4  Linear Regression        Convabuse user  0.906083  0.186048
#
#                                         Coefficients  \
# 0  {0: np.float32(0.78184676), 1: np.float32(-1.7...
# 1  {0: np.float32(5.253629), 1: np.float32(5.8551...
# 2  {0: np.float32(-0.6975128), 1: np.float32(-1.5...
# 3  {0: np.float32(-0.72618026), 1: np.float32(0.7...
# 4  {0: np.float32(-1.0281126), 1: np.float32(0.47...
#
#                                 Feature Coefficients Balance
# 0  {165: np.float32(5.5850844), 382: np.float32(5...   SMOTE
# 1  {379: np.float32(12.949793), 273: np.float32(9...   SMOTE
# 2  {130: np.float32(5.2098746), 169: np.float32(3...   SMOTE
# ...

# %%
sentiment_analysis_logistic_regression_imbalanced.head()
# Out:
#                                     Dataset  \
# 0                      Convabuse prev_agent
# 1                       Convabuse prev_user
# 2                           Convabuse agent
# 3                            Convabuse user
# 4  Dynamically Generated Hate Speech target
#
#                                      Best Parameters  Accuracy  F1-score  \
# 0  Dataset        Convabuse prev_agent\nRegulariz...  0.800079  0.711221
# 1  Dataset        Convabuse prev_user\nRegularize...  0.802862  0.720758
# 2  Dataset        Convabuse agent\nRegularizer   ...  0.800874  0.715039
# 3  Dataset        Convabuse user\nRegularizer    ...  0.852941  0.815526
# 4  Dataset        Dynamically Generated Hate Spee...  0.766610  0.724676
#
#    Ratio                                        Importances  \
# 0    0.0  {0: np.float64(0.0), 1: np.float64(0.0), 2: np...
# 1    0.0  {0: np.float64(-5.551115123125783e-16), 1: np....
# 2    0.0  {0: np.float64(6.2450045135165055e-15), 1: np....
# ...

# %%
sentiment_analysis_logistic_regression_resampled.head()
# Out:
#                 Dataset                                    Best Parameters  \
# 0    Convabuse combined  Dataset        Convabuse combined\nRegularizer...
# 1    Convabuse combined  Dataset        Convabuse combined\nRegularizer...
# 2  Convabuse prev_agent  Dataset        Convabuse prev_agent\nRegulariz...
# 3   Convabuse prev_user  Dataset        Convabuse prev_user\nRegularize...
# 4       Convabuse agent  Dataset        Convabuse agent\nRegularizer   ...
#
#    Accuracy  F1-score  Ratio  \
# 0  0.644405  0.641393    0.0
# 1  0.644405  0.641393    0.0
# 2  0.385013  0.390574    0.0
# 3  0.507653  0.505599    0.0
# 4  0.407474  0.403481    0.0
#
#                                          Importances  \
# 0  {0: np.float32(-0.20279072), 1: np.float32(-0....
# 1  {0: np.float32(-0.20279072), 1: np.float32(-0....
# 2  {0: np.float32(-4.7683716e-07), 1: np.float32(...
# 3  {0: np.float32(0.6713856), 1: np.float32(-0.13...
# 4  {0: np.float32(0.0), 1: np.float32(-2.5301833)...
#
# ...

# %%
sentiment_analysis_logistic_regression_SMOTE.head()
# Out:
#                                     Dataset  \
# 0                      Convabuse prev_agent
# 1                       Convabuse prev_user
# 2                           Convabuse agent
# 3                            Convabuse user
# 4  Dynamically Generated Hate Speech target
#
#                                      Best Parameters  Accuracy  F1-score  \
# 0  Dataset        Convabuse prev_agent\nRegulariz...  0.404610  0.501601
# 1  Dataset        Convabuse prev_user\nRegularize...  0.471383  0.557337
# 2  Dataset        Convabuse agent\nRegularizer   ...  0.434022  0.534386
# 3  Dataset        Convabuse user\nRegularizer    ...  0.702305  0.749320
# 4  Dataset        Dynamically Generated Hate Spee...  0.681241  0.701729
#
#    Ratio                                        Importances  \
# 0    0.0  {0: np.float32(-0.8718583), 1: np.float32(6.90...
# 1    0.0  {0: np.float64(-2.6109102025411186), 1: np.flo...
# 2    0.0  {0: np.float32(-8.6307526e-05), 1: np.float32(...
# ...

# %%
sentiment_analysis_logistic_regression_weighted.head()
# Out:
#                                     Dataset  \
# 0                      Convabuse prev_agent
# 1                       Convabuse prev_user
# 2                           Convabuse agent
# 3                            Convabuse user
# 4  Dynamically Generated Hate Speech target
#
#                                      Best Parameters  Accuracy  F1-score  \
# 0  Dataset        Convabuse prev_agent\nRegulariz...  0.777424  0.716348
# 1  Dataset        Convabuse prev_user\nRegularize...  0.743641  0.731808
# 2  Dataset        Convabuse agent\nRegularizer   ...  0.772655  0.727399
# 3  Dataset        Convabuse user\nRegularizer    ...  0.821145  0.818922
# 4  Dataset        Dynamically Generated Hate Spee...  0.674768  0.696595
#
#    Ratio                                        Importances  \
# 0    0.0  {0: np.float64(0.0), 1: np.float64(2.499710632...
# 1    0.0  {0: np.float64(-1.7708077254893646), 1: np.flo...
# 2    0.0  {0: np.float64(0.663785638920268), 1: np.float...
# ...

# %%
sentiment_analysis_decision_tree_imbalanced.head()
# Out:
#            Model               Dataset  Kernel  Regularization  Accuracy  \
# 0  Decision Tree    Convabuse combined     NaN             NaN  0.812003
# 1  Decision Tree  Convabuse prev_agent     NaN             NaN  0.800079
# 2  Decision Tree   Convabuse prev_user     NaN             NaN  0.800079
# 3  Decision Tree       Convabuse agent     NaN             NaN  0.800079
# 4  Decision Tree        Convabuse user     NaN             NaN  0.821542
#
#    F1-score  Ratio                                    Best Parameters  \
# 0  0.745170    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 1  0.711221    0.0  {'dt_classifier__min_samples_split': 505, 'dt_...
# 2  0.711221    0.0  {'dt_classifier__min_samples_split': 505, 'dt_...
# 3  0.711221    0.0  {'dt_classifier__min_samples_split': 505, 'dt_...
# 4  0.761888    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
#
#                                          Importances  \
# ...

# %%
sentiment_analysis_decision_tree_resampled.head()
# Out:
#            Model               Dataset  Kernel  Regularization  Accuracy  \
# 0  Decision Tree    Convabuse combined     NaN             NaN  0.528324
# 1  Decision Tree  Convabuse prev_agent     NaN             NaN  0.333135
# 2  Decision Tree   Convabuse prev_user     NaN             NaN  0.430133
# 3  Decision Tree       Convabuse agent     NaN             NaN  0.350229
# 4  Decision Tree        Convabuse user     NaN             NaN  0.560127
#
#    F1-score  Ratio                                    Best Parameters  \
# 0  0.525977    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 1  0.328530    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 2  0.424733    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 3  0.352981    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 4  0.556992    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
#
#                                          Importances  \
# ...

# %%
sentiment_analysis_decision_tree_SMOTE.head()
# Out:
#            Model               Dataset  Kernel  Regularization  Accuracy  \
# 0  Decision Tree    Convabuse combined     NaN             NaN  0.434817
# 1  Decision Tree  Convabuse prev_agent     NaN             NaN  0.337440
# 2  Decision Tree   Convabuse prev_user     NaN             NaN  0.356518
# 3  Decision Tree       Convabuse agent     NaN             NaN  0.331479
# 4  Decision Tree        Convabuse user     NaN             NaN  0.474165
#
#    F1-score  Ratio                                    Best Parameters  \
# 0  0.525765    0.0  {'dt_classifier__min_samples_split': 1209, 'dt...
# 1  0.426874    0.0  {'dt_classifier__min_samples_split': 1209, 'dt...
# 2  0.451840    0.0  {'dt_classifier__min_samples_split': 1209, 'dt...
# 3  0.436711    0.0  {'dt_classifier__min_samples_split': 1209, 'dt...
# 4  0.569291    0.0  {'dt_classifier__min_samples_split': 1209, 'dt...
#
#                                          Importances  \
# ...

# %%
sentiment_analysis_decision_tree_weighted.head()
# Out:
#            Model               Dataset  Kernel  Regularization  Accuracy  \
# 0  Decision Tree    Convabuse combined     NaN             NaN  0.394674
# 1  Decision Tree  Convabuse prev_agent     NaN             NaN  0.314785
# 2  Decision Tree   Convabuse prev_user     NaN             NaN  0.286566
# 3  Decision Tree       Convabuse agent     NaN             NaN  0.276232
# 4  Decision Tree        Convabuse user     NaN             NaN  0.511129
#
#    F1-score  Ratio                                    Best Parameters  \
# 0  0.497042    0.0  {'dt_classifier__min_samples_split': 505, 'dt_...
# 1  0.412079    0.0  {'dt_classifier__min_samples_split': 303, 'dt_...
# 2  0.389073    0.0  {'dt_classifier__min_samples_split': 505, 'dt_...
# 3  0.384161    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
# 4  0.582295    0.0  {'dt_classifier__min_samples_split': 404, 'dt_...
#
#                                          Importances  \
# ...

# %%
# Rename Top 10 Importances to Feature Importances
sentiment_analysis_decision_tree_imbalanced = sentiment_analysis_decision_tree_imbalanced.rename(columns={'Top 10 Importances': 'Feature Importances'})
sentiment_analysis_decision_tree_resampled = sentiment_analysis_decision_tree_resampled.rename(columns={'Top 10 Importances': 'Feature Importances'})
sentiment_analysis_decision_tree_SMOTE = sentiment_analysis_decision_tree_SMOTE.rename(columns={'Top 10 Importances': 'Feature Importances'})
sentiment_analysis_decision_tree_weighted = sentiment_analysis_decision_tree_weighted.rename(columns={'Top 10 Importances': 'Feature Importances'})

# %%
sentiment_analysis_neural_network_imbalanced.head()
# Out:
#                 Dataset           Model Optimizer  Accuracy  F1-score  \
# 0    Convabuse combined  Neural Network      Adam  0.839428  0.798344
# 1  Convabuse prev_agent  Neural Network      Adam  0.800079  0.711221
# 2   Convabuse prev_user  Neural Network      Adam  0.813990  0.754209
# 3       Convabuse agent  Neural Network      Adam  0.800079  0.711221
# 4        Convabuse user  Neural Network      Adam  0.858506  0.828545
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.334895      0               16              0.0001
# 1        0.177788      0                8              0.0100
# 2        0.264217      0               64              0.0001
# 3        0.177788      0                8              0.0100
# 4        0.440576      0               32              0.0010
#
#                                          Importances  \
# 0  {0: np.float32(3.8368156), 1: np.float32(3.854...
# 1  {0: np.float32(0.04721532), 1: np.float32(0.24...
# ...

# %%
sentiment_analysis_neural_network_resampled.head()
# Out:
#                 Dataset           Model Optimizer  Accuracy  F1-score  \
# 0    Convabuse combined  Neural Network      Adam  0.809978  0.807973
# 1  Convabuse prev_agent  Neural Network      Adam  0.397734  0.403459
# 2   Convabuse prev_user  Neural Network      Adam  0.651759  0.652532
# 3       Convabuse agent  Neural Network      Adam  0.425363  0.420129
# 4        Convabuse user  Neural Network      Adam  0.763069  0.762479
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.807998      0                8              0.0001
# 1        0.403467      0                8              0.0001
# 2        0.652554      0                8              0.0001
# 3        0.420145      0                8              0.0001
# 4        0.762500      0                8              0.0001
#
#                                          Importances  \
# 0  {0: np.float32(4.244082), 1: np.float32(5.5368...
# 1  {0: np.float32(2.5657277), 1: np.float32(3.864...
# ...

# %%
sentiment_analysis_neural_network_SMOTE_Convabuse.head()
# Out:
#                 Dataset           Model Optimizer  Accuracy  F1-score  \
# 0    Convabuse combined  Neural Network      Adam  0.788553  0.794001
# 1  Convabuse prev_agent  Neural Network      Adam  0.407790  0.490825
# 2   Convabuse prev_user  Neural Network      Adam  0.686010  0.711736
# 3       Convabuse agent  Neural Network      Adam  0.341812  0.419248
# 4        Convabuse user  Neural Network      Adam  0.808824  0.809693
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.399510      0               32               0.001
# 1        0.171275      0               64               0.010
# 2        0.308059      0               16               0.001
# 3        0.147137      0                8               0.010
# 4        0.418444      0               64               0.001
#
#                                          Importances  \
# 0  {0: np.float32(2.9525266), 1: np.float32(3.345...
# 1  {0: np.float32(0.16192095), 1: np.float32(0.44...
# ...

# %%
neural_network_convabuse.head()
# Out:
#      Dataset           Model Optimizer  Accuracy  F1-score  Macro F1-score  \
# 0  Convabuse  Neural Network      Adam  0.606181   0.60689        0.606896
#
#    Ratio  Best Batch Size  Best Learning Rate  \
# 0      0              128                0.01
#
#                                          Importances  \
# 0  {'annotator_id': np.float32(6.3380985), 'bot':...
#
#                                  Feature Importances Balance
# 0  {'annotator_id': np.float32(6.3380985), 'bot':...   SMOTE

# %%
neural_network_mixed_convabuse.head()
# Out:
#      Dataset           Model Optimizer  Accuracy  F1-score  Macro F1-score  \
# 0  Convabuse  Neural Network      Adam  0.841812  0.810947        0.352618
# 1  Convabuse  Neural Network      Adam  0.887122  0.852943        0.435361
#
#    Ratio  Best Batch Size  Best Learning Rate  \
# 0      0                8                0.01
# 1      0              128                0.01
#
#                                          Importances  \
# 0  {'annotator_id': np.float32(1.2898866), 'bot':...
# 1  {'annotator_id': np.float32(4.595064), 'bot': ...
#
#                                  Feature Importances     Balance
# 0  {'umap_2': np.float32(0.9480864), 'umap_1': np...    Weighted
# 1  {'annotator_id': np.float32(4.595064), 'bot': ...  Imbalanced

# %%
neural_network_mixed_SMOTE_convabuse.head()
# Out:
#      Dataset           Model Optimizer  Accuracy  F1-score  Macro F1-score  \
# 0  Convabuse  Neural Network      Adam  0.703965  0.703399        0.703407
#
#    Ratio  Best Batch Size  Best Learning Rate  \
# 0      0              128                0.01
#
#                                          Importances  \
# 0  {'annotator_id': np.float32(7.080337), 'bot': ...
#
#                                  Feature Importances Balance
# 0  {'annotator_id': np.float32(7.080337), 'bot': ...   SMOTE

# %%
neural_network_mixed_mlma.head()
# Out:
#             Dataset           Model Optimizer  Accuracy  F1-score  \
# 0  MLMA Hate Speech  Neural Network      Adam  0.537102  0.504271
# 1  MLMA Hate Speech  Neural Network      Adam  0.608090  0.522185
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.344168      0                8                0.01
# 1        0.288179      0              128                0.01
#
#                                          Importances  \
# 0  {'implicit': np.float32(1.3123981), 'explicit'...
# 1  {'implicit': np.float32(1.7540112), 'explicit'...
#
#                                  Feature Importances     Balance
# 0  {'umap_1': np.float32(1.2173395), 'explicit': ...    Weighted
# 1  {'implicit': np.float32(1.7540112), 'explicit'...  Imbalanced

# %%
neural_network_mixed_SMOTE_mlma.head()
# Out:
#             Dataset           Model Optimizer  Accuracy  F1-score  \
# 0  MLMA Hate Speech  Neural Network      Adam  0.574031  0.558313
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.558313      0              128                0.01
#
#                                          Importances  \
# 0  {'implicit': np.float32(3.3530564), 'explicit'...
#
#                                  Feature Importances Balance
# 0  {'implicit': np.float32(3.3530564), 'explicit'...   SMOTE

# %%
sentiment_analysis_neural_network_SMOTE_DGHS.head()
# Out:
#                                     Dataset           Model Optimizer  \
# 0  Dynamically Generated Hate Speech target  Neural Network      Adam
# 1   Dynamically Generated Hate Speech label  Neural Network      Adam
#
#    Accuracy  F1-score  Macro F1-score  Ratio  Best Batch Size  \
# 0  0.736688  0.727254        0.618605      0                8
# 1  0.724597  0.724628        0.724596      0               64
#
#    Best Learning Rate                                        Importances  \
# 0              0.0001  {0: np.float32(3.4428403), 1: np.float32(3.582...
# 1              0.0010  {0: np.float32(2.6728237), 1: np.float32(2.223...
#
#                                  Feature Importances Balance
# 0  {7: np.float32(3.827003), 112: np.float32(3.83...   SMOTE
# 1  {359: np.float32(3.5152912), 259: np.float32(3...   SMOTE

# %%
neural_network_dghs.head()
# Out:
#                              Dataset           Model Optimizer  Accuracy  \
# 0  Dynamically Generated Hate Speech  Neural Network      Adam  0.845812
#
#    F1-score  Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0  0.844547        0.844547      0              128                0.01
#
#                                          Importances  \
# 0  {'type': np.float32(3.840345), 'annotator': np...
#
#                                  Feature Importances Balance
# 0  {'type': np.float32(3.840345), 'annotator': np...   SMOTE

# %%
sentiment_analysis_neural_network_SMOTE_MLMA.head()
# Out:
#                    Dataset           Model Optimizer  Accuracy  F1-score  \
# 0  MLMA Hate Speech target  Neural Network      Adam  0.823373  0.814986
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.710081      0                8               0.001
#
#                                          Importances  \
# 0  {0: np.float32(2.5610127), 1: np.float32(2.534...
#
#                                  Feature Importances Balance
# 0  {218: np.float32(3.2930164), 347: np.float32(3...   SMOTE

# %%
neural_network_mlma.head()
# Out:
#             Dataset           Model Optimizer  Accuracy  F1-score  \
# 0  MLMA Hate Speech  Neural Network      Adam  0.446725  0.426618
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.426618      0              128                0.01
#
#                                          Importances  \
# 0  {'implicit': np.float32(1.8145995), 'explicit'...
#
#                                  Feature Importances Balance
# 0  {'implicit': np.float32(1.8145995), 'explicit'...   SMOTE

# %%
neural_network_us2020hs.head()
# Out:
#                          Dataset           Model Optimizer  Accuracy  \
# 0  US Elections 2020 Hate Speech  Neural Network      Adam  0.704545
#
#    F1-score  Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0  0.703456        0.703456      0              128                0.01
#
#                                          Importances  \
# 0  {'Trump': np.float32(4.310984), 'Biden': np.fl...
#
#                                  Feature Importances Balance
# 0  {'Trump': np.float32(4.310984), 'Biden': np.fl...   SMOTE

# %%
neural_network_oaa.head()
# Out:
#                   Dataset           Model Optimizer  Accuracy  F1-score  \
# 0  Online Abusive Attacks  Neural Network      Adam  0.998201  0.998201
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.998198      0               32                0.01
#
#                                          Importances  \
# 0  {'Toxic parent tweets': np.float32(30.791134),...
#
#                                  Feature Importances Balance
# 0  {'Toxic parent tweets': np.float32(30.791134),...   SMOTE

# %%
sentiment_analysis_neural_network_weighted.head()
# Out:
#                 Dataset           Model Optimizer  Accuracy  F1-score  \
# 0    Convabuse combined  Neural Network      Adam  0.758744  0.758873
# 1  Convabuse prev_agent  Neural Network      Adam  0.470986  0.542556
# 2   Convabuse prev_user  Neural Network      Adam  0.800079  0.711221
# 3       Convabuse agent  Neural Network      Adam  0.703895  0.675155
# 4        Convabuse user  Neural Network      Adam  0.773450  0.765733
#
#    Macro F1-score  Ratio  Best Batch Size  Best Learning Rate  \
# 0        0.342938      0               32               0.010
# 1        0.174649      0                8               0.001
# 2        0.177788      0                8               0.010
# 3        0.185831      0               16               0.010
# 4        0.339666      0                8               0.010
#
#                                          Importances  \
# 0  {0: np.float32(0.96336144), 1: np.float32(0.58...
# 1  {0: np.float32(0.7703762), 1: np.float32(1.361...
# ...

# %% [markdown]
# ## Results Compilation

# %%
# Compile all of the classification results
logistic_regression = pd.concat([logistic_regression_imbalanced, logistic_regression_resampled, logistic_regression_SMOTE, logistic_regression_weighted]).reset_index(drop=True)
svm_classification = pd.concat([svm_classification_imbalanced, svm_classification_resampled, svm_classification_SMOTE, svm_classification_weighted]).reset_index(drop=True)
dt_classification = pd.concat([dt_classification_imbalanced, dt_classification_resampled, dt_classification_SMOTE, dt_classification_weighted]).reset_index(drop=True)
rf_classification = pd.concat([rf_classification_imbalanced, rf_classification_resampled, rf_classification_SMOTE, rf_classification_weighted]).reset_index(drop=True)
knn_classification = pd.concat([knn_classification_imbalanced, knn_classification_resampled, knn_classification_SMOTE]).reset_index(drop=True)
gb_classification = pd.concat([gb_classification_imbalanced, gb_classification_resampled]).reset_index(drop=True)
xgb_classification = pd.concat([xgb_classification_imbalanced, xgb_classification_resampled, xgb_classification_weighted]).reset_index(drop=True)
neural_network_classification = pd.concat([neural_network_convabuse, neural_network_mixed_convabuse, neural_network_mixed_SMOTE_convabuse, neural_network_mixed_mlma, neural_network_mixed_SMOTE_mlma, neural_network_dghs, neural_network_mlma, neural_network_us2020hs, neural_network_oaa]).reset_index(drop=True)
sentiment_analysis_logistic_regression = pd.concat([sentiment_analysis_logistic_regression_imbalanced, sentiment_analysis_logistic_regression_resampled, sentiment_analysis_logistic_regression_SMOTE, sentiment_analysis_logistic_regression_weighted]).reset_index(drop=True)
sentiment_analysis_decision_tree = pd.concat([sentiment_analysis_decision_tree_imbalanced, sentiment_analysis_decision_tree_resampled, sentiment_analysis_decision_tree_SMOTE, sentiment_analysis_decision_tree_weighted]).reset_index(drop=True)
sentiment_analysis_neural_network = pd.concat([sentiment_analysis_neural_network_imbalanced, sentiment_analysis_neural_network_resampled, sentiment_analysis_neural_network_SMOTE_Convabuse, sentiment_analysis_neural_network_SMOTE_DGHS, sentiment_analysis_neural_network_SMOTE_MLMA, sentiment_analysis_neural_network_weighted]).reset_index(drop=True)

# %%
# Create a unified classification dataframe
classification_results = pd.concat([logistic_regression, svm_classification, dt_classification, rf_classification, knn_classification, gb_classification, xgb_classification, neural_network_classification, sentiment_analysis_logistic_regression, sentiment_analysis_decision_tree, sentiment_analysis_neural_network]).reset_index(drop=True)

classification_results = classification_results[["Model", "Balance", "Dataset", "Regularizer", "Solver", "Accuracy", "F1-score", "Ratio", "Feature Importances", "Permutation Importances", "Best Parameters"]]

# Replace all NaN values with "None" in Feature Importances, Permutation Importances, and Best Parameters
classification_results = classification_results.fillna("None")

# Replace all Dataset values of "US Elections 2020 Election Hate Speech" to "US Elections 2020 Hate Speech"
classification_results['Dataset'] = classification_results['Dataset'].replace("US Elections 2020 Election Hate Speech", "US Elections 2020 Hate Speech")

# Replace all Dataset values containing "Convabuse" with "Convabuse"
classification_results['Dataset'] = classification_results['Dataset'].replace("Convabuse prev_user", "Convabuse")
classification_results['Dataset'] = classification_results['Dataset'].replace("Convabuse prev_agent", "Convabuse")
classification_results['Dataset'] = classification_results['Dataset'].replace("Convabuse agent", "Convabuse")
classification_results['Dataset'] = classification_results['Dataset'].replace("Convabuse user", "Convabuse")
classification_results['Dataset'] = classification_results['Dataset'].replace("Convabuse combined", "Convabuse")

# Replace all Dataset values containing "Dynamically Generated Hate Speech" or "DGHS" with "Dynamically Generated Hate Speech"
classification_results['Dataset'] = classification_results['Dataset'].replace("Dynamically Generated Hate Speech target", "Dynamically Generated Hate Speech")
classification_results['Dataset'] = classification_results['Dataset'].replace("Dynamically Generated Hate Speech label", "Dynamically Generated Hate Speech")
classification_results['Dataset'] = classification_results['Dataset'].replace("DGHS", "Dynamically Generated Hate Speech")

# Rename all Dataset values containing "MLMA Hate Speech target" to "MLMA Hate Speech"
classification_results['Dataset'] = classification_results['Dataset'].replace("MLMA Hate Speech target", "MLMA Hate Speech")

# Rename all Dataset values containing "US2020HS" to "US Elections 2020 Hate Speech"
classification_results['Dataset'] = classification_results['Dataset'].replace("US2020HS", "US Elections 2020 Hate Speech")

classification_results
# Out:
#                    Model     Balance                            Dataset  \
# 0    Logistic Regression  Imbalanced                          Convabuse
# 1    Logistic Regression  Imbalanced  Dynamically Generated Hate Speech
# 2    Logistic Regression  Imbalanced             Online Abusive Attacks
# 3    Logistic Regression  Imbalanced      US Elections 2020 Hate Speech
# 4    Logistic Regression  Imbalanced                   MLMA Hate Speech
# ..                   ...         ...                                ...
# 259       Neural Network    Weighted                          Convabuse
# 260       Neural Network    Weighted                          Convabuse
# 261       Neural Network    Weighted  Dynamically Generated Hate Speech
# 262       Neural Network    Weighted  Dynamically Generated Hate Speech
# 263       Neural Network    Weighted                   MLMA Hate Speech
#
#     Regularizer     Solver  Accuracy  F1-score Ratio  \
# ...

# %%
classification_results[classification_results["Dataset"] == "US Elections 2020 Hate Speech"].sort_values(by="F1-score", ascending=False)
# Out:
#                       Model     Balance                        Dataset  \
# 29   Support Vector Machine  Imbalanced  US Elections 2020 Hate Speech
# 147       Gradient Boosting  Imbalanced  US Elections 2020 Hate Speech
# 83            Decision Tree  Imbalanced  US Elections 2020 Hate Speech
# 137       Gradient Boosting  Imbalanced  US Elections 2020 Hate Speech
# 123     K-Nearest Neighbors  Imbalanced  US Elections 2020 Hate Speech
# 113           Random Forest       SMOTE  US Elections 2020 Hate Speech
# 103           Random Forest  imbalanced  US Elections 2020 Hate Speech
# 31   Support Vector Machine  Imbalanced  US Elections 2020 Hate Speech
# 30   Support Vector Machine  Imbalanced  US Elections 2020 Hate Speech
# 98            Decision Tree    Weighted  US Elections 2020 Hate Speech
# 118           Random Forest    Weighted  US Elections 2020 Hate Speech
# 74   Support Vector Machine    Weighted  US Elections 2020 Hate Speech
# ...

# %%
# Create a unified classification dataframe
feature_classification_results = pd.concat([logistic_regression, svm_classification, dt_classification, rf_classification, knn_classification, gb_classification, xgb_classification]).reset_index(drop=True)

feature_classification_results = feature_classification_results[["Model", "Balance", "Dataset", "Regularizer", "Solver", "Accuracy", "F1-score", "Ratio", "Feature Importances", "Permutation Importances", "Best Parameters"]]

# Replace all NaN values with "None" in Feature Importances, Permutation Importances, and Best Parameters
feature_classification_results = feature_classification_results.fillna("None")

# Replace all Dataset values of "US Elections 2020 Election Hate Speech" to "US Elections 2020 Hate Speech"
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("US Elections 2020 Election Hate Speech", "US Elections 2020 Hate Speech")

# Replace all Dataset values containing "Convabuse" with "Convabuse"
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Convabuse prev_user", "Convabuse")
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Convabuse prev_agent", "Convabuse")
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Convabuse agent", "Convabuse")
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Convabuse user", "Convabuse")
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Convabuse combined", "Convabuse")

# Replace all Dataset values containing "Dynamically Generated Hate Speech" or "DGHS" with "Dynamically Generated Hate Speech"
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Dynamically Generated Hate Speech target", "Dynamically Generated Hate Speech")
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("Dynamically Generated Hate Speech label", "Dynamically Generated Hate Speech")
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("DGHS", "Dynamically Generated Hate Speech")

# Rename all Dataset values containing "MLMA Hate Speech target" to "MLMA Hate Speech"
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("MLMA Hate Speech target", "MLMA Hate Speech")

# Rename all Dataset values containing "US2020HS" to "US Elections 2020 Hate Speech"
feature_classification_results['Dataset'] = feature_classification_results['Dataset'].replace("US2020HS", "US Elections 2020 Hate Speech")

feature_classification_results
# Out:
#                    Model     Balance                            Dataset  \
# 0    Logistic Regression  Imbalanced                          Convabuse
# 1    Logistic Regression  Imbalanced  Dynamically Generated Hate Speech
# 2    Logistic Regression  Imbalanced             Online Abusive Attacks
# 3    Logistic Regression  Imbalanced      US Elections 2020 Hate Speech
# 4    Logistic Regression  Imbalanced                   MLMA Hate Speech
# ..                   ...         ...                                ...
# 154    Gradient Boosting    Weighted                          Convabuse
# 155    Gradient Boosting    Weighted  Dynamically Generated Hate Speech
# 156    Gradient Boosting        None             Online Abusive Attacks
# 157    Gradient Boosting    Weighted      US Elections 2020 Hate Speech
# 158    Gradient Boosting    Weighted                   MLMA Hate Speech
#
#     Regularizer     Solver  Accuracy  F1-score  \
# 0            l1  liblinear  0.885533  0.852027
# ...

# %%
# Create a unified classification dataframe
embedding_classification_results = pd.concat([sentiment_analysis_logistic_regression, sentiment_analysis_decision_tree, sentiment_analysis_neural_network]).reset_index(drop=True)

embedding_classification_results = embedding_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score", "Ratio", "Feature Importances", "Best Parameters"]]

# Replace all NaN values with "None" in Feature Importances, Permutation Importances, and Best Parameters
embedding_classification_results = embedding_classification_results.fillna("None")

# Replace all Dataset values of "US Elections 2020 Election Hate Speech" to "US Elections 2020 Hate Speech"
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("US Elections 2020 Election Hate Speech", "US Elections 2020 Hate Speech")

# Replace all Dataset values containing "Convabuse" with "Convabuse"
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Convabuse prev_user", "Convabuse")
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Convabuse prev_agent", "Convabuse")
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Convabuse agent", "Convabuse")
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Convabuse user", "Convabuse")
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Convabuse combined", "Convabuse")

# Replace all Dataset values containing "Dynamically Generated Hate Speech" or "DGHS" with "Dynamically Generated Hate Speech"
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Dynamically Generated Hate Speech target", "Dynamically Generated Hate Speech")
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("Dynamically Generated Hate Speech label", "Dynamically Generated Hate Speech")
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("DGHS", "Dynamically Generated Hate Speech")

# Rename all Dataset values containing "MLMA Hate Speech target" to "MLMA Hate Speech"
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("MLMA Hate Speech target", "MLMA Hate Speech")

# Rename all Dataset values containing "US2020HS" to "US Elections 2020 Hate Speech"
embedding_classification_results['Dataset'] = embedding_classification_results['Dataset'].replace("US2020HS", "US Elections 2020 Hate Speech")

embedding_classification_results
# Out:
#                   Model     Balance                            Dataset  \
# 0   Logistic Regression  Imbalanced                          Convabuse
# 1   Logistic Regression  Imbalanced                          Convabuse
# 2   Logistic Regression  Imbalanced                          Convabuse
# 3   Logistic Regression  Imbalanced                          Convabuse
# 4   Logistic Regression  Imbalanced  Dynamically Generated Hate Speech
# ..                  ...         ...                                ...
# 89       Neural Network    Weighted                          Convabuse
# 90       Neural Network    Weighted                          Convabuse
# 91       Neural Network    Weighted  Dynamically Generated Hate Speech
# 92       Neural Network    Weighted  Dynamically Generated Hate Speech
# 93       Neural Network    Weighted                   MLMA Hate Speech
#
#     Accuracy  F1-score  Ratio  \
# 0   0.800079  0.711221    0.0
# 1   0.802862  0.720758    0.0
# ...

# %%
# Compile all of the regression results
linear_regression = pd.concat([linear_regression_imbalanced, linear_regression_resampled, linear_regression_SMOTE]).reset_index(drop=True)
sentiment_analysis_linear_regression = pd.concat([sentiment_analysis_linear_regression_imbalanced, sentiment_analysis_linear_regression_resampled, sentiment_analysis_linear_regression_SMOTE]).reset_index(drop=True)
regression_results = pd.concat([linear_regression, svm_regression_resampled, dt_regression_resampled, gb_regression_resampled, xgb_regression_resampled, knn_regression_resampled, sentiment_analysis_linear_regression]).reset_index(drop=True)
regression_results = regression_results[["Model", "Dataset", "Balance", "RMSE", "R2", "Feature Coefficients", "Best Parameters"]]

# Replace all Dataset values containing "Convabuse" with "Convabuse"
regression_results['Dataset'] = regression_results['Dataset'].replace("Convabuse prev_user", "Convabuse")
regression_results['Dataset'] = regression_results['Dataset'].replace("Convabuse prev_agent", "Convabuse")
regression_results['Dataset'] = regression_results['Dataset'].replace("Convabuse agent", "Convabuse")
regression_results['Dataset'] = regression_results['Dataset'].replace("Convabuse user", "Convabuse")
regression_results['Dataset'] = regression_results['Dataset'].replace("Convabuse combined", "Convabuse")

# Replace all Dataset values containing "Dynamically Generated Hate Speech" or "DGHS" with "Dynamically Generated Hate Speech"
regression_results['Dataset'] = regression_results['Dataset'].replace("Dynamically Generated Hate Speech target", "Dynamically Generated Hate Speech")
regression_results['Dataset'] = regression_results['Dataset'].replace("Dynamically Generated Hate Speech label", "Dynamically Generated Hate Speech")
regression_results['Dataset'] = regression_results['Dataset'].replace("DGHS", "Dynamically Generated Hate Speech")

# Rename all Dataset values containing "MLMA Hate Speech target" to "MLMA Hate Speech"
regression_results['Dataset'] = regression_results['Dataset'].replace("MLMA Hate Speech target", "MLMA Hate Speech")

# Fill NaN values with "None"
regression_results = regression_results.fillna("None")
regression_results
# Out:
# /tmp/ipython-input-3828923713.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   regression_results = pd.concat([linear_regression, svm_regression_resampled, dt_regression_resampled, gb_regression_resampled, xgb_regression_resampled, knn_regression_resampled, sentiment_analysis_linear_regression]).reset_index(drop=True)
#                      Model                            Dataset     Balance  \
# 0        Linear Regression                          Convabuse  Imbalanced
# 1        Linear Regression  Dynamically Generated Hate Speech  Imbalanced
# 2        Linear Regression      US Elections 2020 Hate Speech  Imbalanced
# 3        Linear Regression                   MLMA Hate Speech  Imbalanced
# ...

# %%
kmeans_clustering = pd.concat([kmeans_clustering_imbalanced, kmeans_clustering_resampled, kmeans_clustering_SMOTE]).reset_index(drop=True)
kmeans_clustering
# Out:
#                               Dataset  Best Model Silhouette Score  \
# 0                           Convabuse                     0.513327
# 1   Dynamically Generated Hate Speech                     0.603673
# 2              Online Abusive Attacks                     0.400000
# 3       US Elections 2020 Hate Speech                     0.666667
# 4                    MLMA Hate Speech                     0.659905
# 5                           Convabuse                     0.589957
# 6   Dynamically Generated Hate Speech                     0.569834
# 7              Online Abusive Attacks                     0.142857
# 8       US Elections 2020 Hate Speech                     0.636364
# 9                    MLMA Hate Speech                     0.448927
# 10                          Convabuse                     0.624671
# 11  Dynamically Generated Hate Speech                     0.605949
# 12      US Elections 2020 Hate Speech                     0.608510
# ...

# %% [markdown]
# ## Dataset Results

# %%
# Get all classification results for Convabuse
classification_results[classification_results["Dataset"] == "Convabuse"][classification_results["F1-score"] > 0.6][classification_results["Model"] == "Neural Network"].sort_values(by="F1-score", ascending=False)
# Out:
# /tmp/ipython-input-301479233.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "Convabuse"][classification_results["F1-score"] > 0.6][classification_results["Model"] == "Neural Network"].sort_values(by="F1-score", ascending=False)
# /tmp/ipython-input-301479233.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "Convabuse"][classification_results["F1-score"] > 0.6][classification_results["Model"] == "Neural Network"].sort_values(by="F1-score", ascending=False)
#               Model     Balance    Dataset Regularizer Solver  Accuracy  \
# 161  Neural Network  Imbalanced  Convabuse        None   None  0.887122
# 236  Neural Network  Imbalanced  Convabuse        None   None  0.858506
# 160  Neural Network    Weighted  Convabuse        None   None  0.841812
# ...

# %%
# Get all classification results for DGHS
classification_results[classification_results["Dataset"] == "Dynamically Generated Hate Speech"][classification_results["Model"] == "Neural Network"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
# Out:
# /tmp/ipython-input-1319333015.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "Dynamically Generated Hate Speech"][classification_results["Model"] == "Neural Network"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
# /tmp/ipython-input-1319333015.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "Dynamically Generated Hate Speech"][classification_results["Model"] == "Neural Network"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
#               Model     Balance                            Dataset  \
# 166  Neural Network       SMOTE  Dynamically Generated Hate Speech
# 245  Neural Network    Resample  Dynamically Generated Hate Speech
# 237  Neural Network  Imbalanced  Dynamically Generated Hate Speech
# ...

# %%
# Get all classification results for OAA
classification_results[classification_results["Dataset"] == "Online Abusive Attacks"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
# Out:
# /tmp/ipython-input-2224288063.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "Online Abusive Attacks"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
#                       Model     Balance                 Dataset Regularizer  \
# 169          Neural Network       SMOTE  Online Abusive Attacks        None
# 131     K-Nearest Neighbors       SMOTE  Online Abusive Attacks        None
# 122     K-Nearest Neighbors        None  Online Abusive Attacks        None
# 28   Support Vector Machine  Imbalanced  Online Abusive Attacks        None
# 82            Decision Tree  Imbalanced  Online Abusive Attacks        None
# 102           Random Forest  imbalanced  Online Abusive Attacks        None
# 112           Random Forest       SMOTE  Online Abusive Attacks        None
# 117           Random Forest    Weighted  Online Abusive Attacks        None
# ...

# %%
# Get all classification results for US2020HS
classification_results[classification_results["Dataset"] == "US Elections 2020 Hate Speech"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
# Out:
# /tmp/ipython-input-437511567.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "US Elections 2020 Hate Speech"][classification_results["F1-score"] > 0.6].sort_values(by="F1-score", ascending=False)
#                       Model     Balance                        Dataset  \
# 29   Support Vector Machine  Imbalanced  US Elections 2020 Hate Speech
# 147       Gradient Boosting  Imbalanced  US Elections 2020 Hate Speech
# 83            Decision Tree  Imbalanced  US Elections 2020 Hate Speech
# 123     K-Nearest Neighbors  Imbalanced  US Elections 2020 Hate Speech
# 137       Gradient Boosting  Imbalanced  US Elections 2020 Hate Speech
# 103           Random Forest  imbalanced  US Elections 2020 Hate Speech
# 113           Random Forest       SMOTE  US Elections 2020 Hate Speech
# 31   Support Vector Machine  Imbalanced  US Elections 2020 Hate Speech
# ...

# %%
# Get all classification results for MLMA Hate Speech
classification_results[classification_results["Dataset"] == "MLMA Hate Speech"][classification_results["F1-score"] > 0.5][classification_results["Model"] == "Neural Network"].sort_values(by="F1-score", ascending=False)
# Out:
# /tmp/ipython-input-1723158704.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "MLMA Hate Speech"][classification_results["F1-score"] > 0.5][classification_results["Model"] == "Neural Network"].sort_values(by="F1-score", ascending=False)
# /tmp/ipython-input-1723158704.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   classification_results[classification_results["Dataset"] == "MLMA Hate Speech"][classification_results["F1-score"] > 0.5][classification_results["Model"] == "Neural Network"].sort_values(by="F1-score", ascending=False)
#               Model     Balance           Dataset Regularizer Solver  \
# 255  Neural Network       SMOTE  MLMA Hate Speech        None   None
# 263  Neural Network    Weighted  MLMA Hate Speech        None   None
# 239  Neural Network  Imbalanced  MLMA Hate Speech        None   None
# ...

# %% [markdown]
# ## Compile the Best Results

# %%
# Group classification results by dataset and sort by accuracy in descending order
best_accuracy_classification_results = classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["Accuracy"], ascending=False).head(1)).reset_index(drop=True)
best_accuracy_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
# Out:
# /tmp/ipython-input-3624161802.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_accuracy_classification_results = classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["Accuracy"], ascending=False).head(1)).reset_index(drop=True)
#                  Model     Balance                            Dataset  \
# 0       Neural Network  Imbalanced                          Convabuse
# 1        Random Forest   Resampled  Dynamically Generated Hate Speech
# 2       Neural Network       SMOTE                   MLMA Hate Speech
# 3       Neural Network       SMOTE             Online Abusive Attacks
# 4  Logistic Regression  Imbalanced      US Elections 2020 Hate Speech
#
# ...

# %%
# Group classification results by dataset and sort by f1-score in descending order
best_f1_classification_results = classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["F1-score"], ascending=False).head(1)).reset_index(drop=True)
best_f1_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
# Out:
# /tmp/ipython-input-4186725504.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_f1_classification_results = classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["F1-score"], ascending=False).head(1)).reset_index(drop=True)
#                     Model     Balance                            Dataset  \
# 0     Logistic Regression    Weighted                          Convabuse
# 1           Random Forest   Resampled  Dynamically Generated Hate Speech
# 2          Neural Network       SMOTE                   MLMA Hate Speech
# 3          Neural Network       SMOTE             Online Abusive Attacks
# ...

# %%
# Combine indices 0 to 2 from the best_feature_accuracy_classification_results and indices 3 to 4 from the best_feature_f1_classification_results for the best final results
best_final_results = pd.concat([best_accuracy_classification_results.iloc[0:3], best_f1_classification_results.iloc[3:5]]).reset_index(drop=True)
best_final_results = best_final_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
best_final_results
# Out:
#                     Model     Balance                            Dataset  \
# 0          Neural Network  Imbalanced                          Convabuse
# 1           Random Forest   Resampled  Dynamically Generated Hate Speech
# 2          Neural Network       SMOTE                   MLMA Hate Speech
# 3          Neural Network       SMOTE             Online Abusive Attacks
# 4  Support Vector Machine  Imbalanced      US Elections 2020 Hate Speech
#
#    Accuracy  F1-score
# 0  0.887122  0.852943
# 1  0.852399  0.851308
# 2  0.823373  0.814986
# 3  0.998201  0.998201
# 4  0.883139  0.828334

# %%
# Group classification results by dataset and sort by accuracy in descending order
best_feature_accuracy_classification_results = feature_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["Accuracy"], ascending=False).head(1)).reset_index(drop=True)
best_feature_accuracy_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
# Out:
# /tmp/ipython-input-1321491069.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_feature_accuracy_classification_results = feature_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["Accuracy"], ascending=False).head(1)).reset_index(drop=True)
#                  Model     Balance                            Dataset  \
# 0  Logistic Regression  Imbalanced                          Convabuse
# 1        Random Forest   Resampled  Dynamically Generated Hate Speech
# 2        Random Forest  imbalanced                   MLMA Hate Speech
# 3  K-Nearest Neighbors       SMOTE             Online Abusive Attacks
# ...

# %%
# Group classification results by dataset and sort by f1-score in descending order
best_feature_f1_classification_results = feature_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["F1-score"], ascending=False).head(1)).reset_index(drop=True)
best_feature_f1_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
# Out:
# /tmp/ipython-input-3935630864.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_feature_f1_classification_results = feature_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["F1-score"], ascending=False).head(1)).reset_index(drop=True)
#                     Model     Balance                            Dataset  \
# 0     Logistic Regression    Weighted                          Convabuse
# 1           Random Forest   Resampled  Dynamically Generated Hate Speech
# 2     K-Nearest Neighbors   Resampled                   MLMA Hate Speech
# 3     K-Nearest Neighbors       SMOTE             Online Abusive Attacks
# ...

# %%
# Group classification results by dataset and sort by accuracy in descending order
best_embedding_accuracy_classification_results = embedding_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["Accuracy"], ascending=False).head(1)).reset_index(drop=True)
best_embedding_accuracy_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
# Out:
# /tmp/ipython-input-1422684289.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_embedding_accuracy_classification_results = embedding_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["Accuracy"], ascending=False).head(1)).reset_index(drop=True)
#             Model     Balance                            Dataset  Accuracy  \
# 0  Neural Network  Imbalanced                          Convabuse  0.858506
# 1  Neural Network    Resample  Dynamically Generated Hate Speech  0.813785
# 2  Neural Network       SMOTE                   MLMA Hate Speech  0.823373
#
#    F1-score
# 0  0.828545
# 1  0.810761
# 2  0.814986

# %%
# Group classification results by dataset and sort by f1-score in descending order
best_embedding_f1_classification_results = embedding_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["F1-score"], ascending=False).head(1)).reset_index(drop=True)
best_embedding_f1_classification_results[["Model", "Balance", "Dataset", "Accuracy", "F1-score"]]
# Out:
# /tmp/ipython-input-703808549.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_embedding_f1_classification_results = embedding_classification_results.groupby("Dataset").apply(lambda x: x.sort_values(["F1-score"], ascending=False).head(1)).reset_index(drop=True)
#             Model     Balance                            Dataset  Accuracy  \
# 0  Neural Network  Imbalanced                          Convabuse  0.858506
# 1  Neural Network    Resample  Dynamically Generated Hate Speech  0.813785
# 2  Neural Network       SMOTE                   MLMA Hate Speech  0.823373
#
#    F1-score
# 0  0.828545
# 1  0.810761
# 2  0.814986

# %%
# Group regression results by dataset and sort by R2 in descending order
best_r2_regression_results = regression_results.groupby("Dataset").apply(lambda x: x.sort_values(["R2"], ascending=False).head(1)).reset_index(drop=True)
best_r2_regression_results
# Out:
# /tmp/ipython-input-3350951846.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_r2_regression_results = regression_results.groupby("Dataset").apply(lambda x: x.sort_values(["R2"], ascending=False).head(1)).reset_index(drop=True)
#                Model                            Dataset     Balance  \
# 0  Linear Regression                          Convabuse  Imbalanced
# 1  Linear Regression  Dynamically Generated Hate Speech       SMOTE
# 2  Linear Regression                   MLMA Hate Speech   Resampled
# 3  Linear Regression             Online Abusive Attacks   Resampled
# 4  Linear Regression      US Elections 2020 Hate Speech       SMOTE
#
# ...

# %%
# Group regression results by dataset and sort by RMSE in ascending order
best_rmse_regression_results = regression_results.groupby("Dataset").apply(lambda x: x.sort_values(["RMSE"], ascending=True).head(1)).reset_index(drop=True)
best_rmse_regression_results
# Out:
# /tmp/ipython-input-1268367184.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_rmse_regression_results = regression_results.groupby("Dataset").apply(lambda x: x.sort_values(["RMSE"], ascending=True).head(1)).reset_index(drop=True)
#                Model                            Dataset     Balance  \
# 0  Linear Regression                          Convabuse  Imbalanced
# 1  Linear Regression  Dynamically Generated Hate Speech       SMOTE
# 2  Linear Regression                   MLMA Hate Speech  Imbalanced
# 3  Linear Regression             Online Abusive Attacks   Resampled
# 4  Linear Regression      US Elections 2020 Hate Speech  Imbalanced
#
# ...

# %%
# Group regression results by dataset and sort by silhouette score in descending order
best_silhouette_score_clustering_results = kmeans_clustering.groupby("Dataset").apply(lambda x: x.sort_values(["Chosen Model Silhouette Score"], ascending=False).head(1)).reset_index(drop=True)
best_silhouette_score_clustering_results
# Out:
# /tmp/ipython-input-4155619936.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_silhouette_score_clustering_results = kmeans_clustering.groupby("Dataset").apply(lambda x: x.sort_values(["Chosen Model Silhouette Score"], ascending=False).head(1)).reset_index(drop=True)
#                              Dataset  Best Model Silhouette Score  \
# 0                          Convabuse                     0.624671
# 1  Dynamically Generated Hate Speech                     0.569834
# 2                   MLMA Hate Speech                     0.659905
# 3             Online Abusive Attacks                     0.142857
# 4      US Elections 2020 Hate Speech                     0.666667
#
# ...

# %%
# Group regression results by dataset and sort by inertia in ascending order
best_inertia_clustering_results = kmeans_clustering.groupby("Dataset").apply(lambda x: x.sort_values(["Chosen Model Inertia"], ascending=False).head(1)).reset_index(drop=True)
best_inertia_clustering_results
# Out:
# /tmp/ipython-input-2773436389.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_inertia_clustering_results = kmeans_clustering.groupby("Dataset").apply(lambda x: x.sort_values(["Chosen Model Inertia"], ascending=False).head(1)).reset_index(drop=True)
#                              Dataset  Best Model Silhouette Score  \
# 0                          Convabuse                     0.624671
# 1  Dynamically Generated Hate Speech                     0.605949
# 2                   MLMA Hate Speech                     0.197870
# 3             Online Abusive Attacks                     0.142857
# 4      US Elections 2020 Hate Speech                     0.608510
#
# ...

# %% [markdown]
# ## Output Files

# %%
# Output the classification, regression, and clustering results as separate csv files
classification_results.to_csv(f"{results_path}classification_results.csv", index=False)
feature_classification_results.to_csv(f"{results_path}feature_classification_results.csv", index=False)
embedding_classification_results.to_csv(f"{results_path}embedding_classification_results.csv", index=False)
regression_results.to_csv(f"{results_path}regression_results.csv", index=False)
kmeans_clustering.to_csv(f"{results_path}kmeans_clustering_results.csv", index=False)

# %%
# Output the best classification, regression, and clustering results as separate csv files
best_accuracy_classification_results.to_csv(f"{results_path}best_accuracy_classification_results.csv", index=False)
best_f1_classification_results.to_csv(f"{results_path}best_f1_classification_results.csv", index=False)
best_r2_regression_results.to_csv(f"{results_path}best_r2_regression_results.csv", index=False)
best_feature_accuracy_classification_results.to_csv(f"{results_path}best_feature_accuracy_classification_results.csv", index=False)
best_feature_f1_classification_results.to_csv(f"{results_path}best_feature_f1_classification_results.csv", index=False)
best_embedding_accuracy_classification_results.to_csv(f"{results_path}best_embedding_accuracy_classification_results.csv", index=False)
best_embedding_f1_classification_results.to_csv(f"{results_path}best_embedding_f1_classification_results.csv", index=False)
best_rmse_regression_results.to_csv(f"{results_path}best_rmse_regression_results.csv", index=False)
best_silhouette_score_clustering_results.to_csv(f"{results_path}best_silhouette_score_clustering_results.csv", index=False)
best_inertia_clustering_results.to_csv(f"{results_path}best_inertia_clustering_results.csv", index=False)
